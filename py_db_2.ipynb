# %%
import sqlalchemy

# %%
# создаем engine
engine = sqlalchemy.create_engine('postgresql://postgres:admin@localhost:5432/postgres')
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/postgres)

# %%
con = engine.connect()

# %% [markdown]
# Агрегирующие функции

# %%
# найдем максимальную стоимость проката
con.execute("""
SELECT MAX(rental_rate) FROM film;
""").fetchall()
# Out:
# [(Decimal('4.99'),)]

# %%
# посчитаем среднюю продолжительность фильма
con.execute("""
SELECT AVG(length) FROM film;
""").fetchall()
# Out:
# [(Decimal('115.2720000000000000'),)]

# %%
# сколько уникальных имен актеров?
con.execute("""
SELECT COUNT(DISTINCT first_name) FROM actor;
""").fetchall()
# Out:
# [(128,)]

# %%
# посчитаем сумму и средние продажи по конкретному продавцу
con.execute("""
SELECT SUM(amount), AVG(amount) FROM payment
WHERE staff_id = 1;
""").fetchall()
# Out:
# [(Decimal('30252.12'), Decimal('4.1486725178277564'))]

# %% [markdown]
# Вложенные запросы

# %%
# найдем все фильмы с продолжительностью ваше среднего

# так работать не будет
con.execute("""
SELECT title, length  FROM film
WHERE length >= AVG(length);
""").fetchall()
# Out:
# ---------------------------------------------------------------------------
# GroupingError                             Traceback (most recent call last)
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# GroupingError: ОШИБКА:  агрегатные функции нельзя применять в конструкции WHERE
# LINE 3: WHERE length >= AVG(length);
#                         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipykernel_72571/1624840473.py in <module>
#       2
#       3 # так работать не будет
# ----> 4 con.execute("""
#       5 SELECT title, length  FROM film
#       6 WHERE length >= AVG(length);
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1246             )
#    1247
# -> 1248             return self._exec_driver_sql(
#    1249                 statement,
#    1250                 multiparams,
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1545
#    1546         dialect = self.dialect
# -> 1547         ret = self._execute_context(
#    1548             dialect,
#    1549             dialect.execution_ctx_cls._init_statement,
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                             break
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#    1773                     )
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.GroupingError) ОШИБКА:  агрегатные функции нельзя применять в конструкции WHERE
# LINE 3: WHERE length >= AVG(length);
#                         ^
#
# [SQL:
# SELECT title, length  FROM film
# WHERE length >= AVG(length);
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
con.execute("""
SELECT title, length FROM film
WHERE length >= (
    SELECT AVG(length) FROM film);
""").fetchmany(10)
# Out:
# [('Chamber Italian', 117),
#  ('Affair Prejudice', 117),
#  ('African Egg', 130),
#  ('Agent Truman', 169),
#  ('Alamo Videotape', 126),
#  ('Alaska Phantom', 136),
#  ('Ali Forever', 150),
#  ('Alley Evolution', 180),
#  ('American Circus', 129),
#  ('Analyze Hoosiers', 181)]

# %%
# найдем названия фильмов, стоимость проката которых не максимальная
con.execute("""SELECT title, rental_rate FROM film
WHERE rental_rate < (SELECT MAX(rental_rate) FROM film)
ORDER BY rental_rate DESC;
""").fetchall()
# Out:
# ---------------------------------------------------------------------------
# GroupingError                             Traceback (most recent call last)
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# GroupingError: ОШИБКА:  столбец "film.rental_rate" должен фигурировать в предложении GROUP BY или использоваться в агрегатной функции
# LINE 3: ORDER BY rental_rate DESC;
#                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipykernel_72571/1704140441.py in <module>
#       1 # найдем названия фильмов, стоимость проката которых не максимальная
# ----> 2 con.execute("""SELECT COUNT(title) FROM film
#       3 WHERE rental_rate < (SELECT MAX(rental_rate) FROM film)
#       4 ORDER BY rental_rate DESC;
#       5 """).fetchall()
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1246             )
#    1247
# -> 1248             return self._exec_driver_sql(
#    1249                 statement,
#    1250                 multiparams,
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1545
#    1546         dialect = self.dialect
# -> 1547         ret = self._execute_context(
#    1548             dialect,
#    1549             dialect.execution_ctx_cls._init_statement,
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                             break
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#    1773                     )
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.GroupingError) ОШИБКА:  столбец "film.rental_rate" должен фигурировать в предложении GROUP BY или использоваться в агрегатной функции
# LINE 3: ORDER BY rental_rate DESC;
#                  ^
#
# [SQL: SELECT COUNT(title) FROM film
# WHERE rental_rate < (SELECT MAX(rental_rate) FROM film)
# ORDER BY rental_rate DESC;
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# Группировки

# %%
# посчитаем количество актеров в разрезе фамилий (найдем однофамильцев)
con.execute("""
SELECT last_name, COUNT(*) FROM actor
GROUP BY last_name
ORDER BY COUNT(*) DESC;
""").fetchmany(10)
# Out:
# [('Kilmer', 5),
#  ('Temple', 4),
#  ('Nolte', 4),
#  ('Williams', 3),
#  ('Peck', 3),
#  ('Degeneres', 3),
#  ('Akroyd', 3),
#  ('Harris', 3),
#  ('Hoffman', 3),
#  ('Zellweger', 3)]

# %%
# посчитаем количество фильмов в разрезе рейтингов (распределение рейтингов)
con.execute("""
SELECT rating, COUNT(*) FROM film
GROUP BY rating
ORDER BY COUNT(title) DESC;
""").fetchall()
# Out:
# [('PG-13', 223), ('NC-17', 210), ('R', 195), ('PG', 194), ('G', 178)]

# %%
# найдем максимальные продажи в разрезе продавцов
con.execute("""
SELECT staff_id, MAX(amount) FROM payment
GROUP BY staff_id;
""").fetchall()
# Out:
# [(1, Decimal('11.99')), (2, Decimal('11.99'))]

# %%
# найдем средние продажи каждого продавца каждому покупателю
con.execute("""
SELECT staff_id, customer_id, AVG(amount) FROM payment
GROUP BY staff_id, customer_id
ORDER BY AVG(amount) DESC;
""").fetchall()
# Out:
# [(2, 372, Decimal('6.6053846153846154')),
#  (2, 558, Decimal('6.4515384615384615')),
#  (1, 483, Decimal('6.1150000000000000')),
#  (2, 17, Decimal('6.1011111111111111')),
#  (2, 307, Decimal('5.9900000000000000')),
#  (2, 331, Decimal('5.9900000000000000')),
#  (2, 544, Decimal('5.9900000000000000')),
#  (2, 321, Decimal('5.9900000000000000')),
#  (2, 3, Decimal('5.9066666666666667')),
#  (2, 505, Decimal('5.8650000000000000')),
#  (2, 14, Decimal('5.8471428571428571')),
#  (2, 187, Decimal('5.8321052631578947')),
#  (2, 92, Decimal('5.8233333333333333')),
#  (1, 16, Decimal('5.7900000000000000')),
#  (2, 209, Decimal('5.7757142857142857')),
#  (1, 345, Decimal('5.7677777777777778')),
#  (1, 285, Decimal('5.7592307692307692')),
#  (2, 87, Decimal('5.7592307692307692')),
#  (1, 464, Decimal('5.7400000000000000')),
#  (1, 363, Decimal('5.7400000000000000')),
#  (1, 509, Decimal('5.7400000000000000')),
#  (1, 531, Decimal('5.7400000000000000')),
#  (1, 134, Decimal('5.7400000000000000')),
#  (2, 472, Decimal('5.7400000000000000')),
#  (1, 178, Decimal('5.7268421052631579')),
#  (2, 103, Decimal('5.7233333333333333')),
#  (1, 65, Decimal('5.7172727272727273')),
#  (2, 349, Decimal('5.7172727272727273')),
#  (2, 47, Decimal('5.6900000000000000')),
#  (2, 310, Decimal('5.6566666666666667')),
#  (2, 583, Decimal('5.6566666666666667')),
#  (2, 272, Decimal('5.6566666666666667')),
#  (2, 542, Decimal('5.6566666666666667')),
#  (1, 181, Decimal('5.6566666666666667')),
#  (2, 2, Decimal('5.6566666666666667')),
#  (1, 293, Decimal('5.6263636363636364')),
#  (2, 19, Decimal('5.6150000000000000')),
#  (1, 67, Decimal('5.6150000000000000')),
#  (1, 487, Decimal('5.5733333333333333')),
#  (2, 554, Decimal('5.5614285714285714')),
#  (2, 462, Decimal('5.4900000000000000')),
#  (2, 49, Decimal('5.4900000000000000')),
#  (2, 13, Decimal('5.4900000000000000')),
#  (2, 429, Decimal('5.4445454545454545')),
#  (1, 302, Decimal('5.4445454545454545')),
#  (1, 82, Decimal('5.4445454545454545')),
#  (2, 205, Decimal('5.4344444444444444')),
#  (2, 194, Decimal('5.4185714285714286')),
#  (2, 309, Decimal('5.4185714285714286')),
#  (2, 508, Decimal('5.4185714285714286')),
#  (1, 305, Decimal('5.4185714285714286')),
#  (1, 515, Decimal('5.4185714285714286')),
#  (2, 311, Decimal('5.3900000000000000')),
#  (1, 225, Decimal('5.3900000000000000')),
#  (1, 273, Decimal('5.3900000000000000')),
#  (1, 311, Decimal('5.3900000000000000')),
#  (1, 19, Decimal('5.3900000000000000')),
#  (2, 493, Decimal('5.3650000000000000')),
#  (2, 223, Decimal('5.3650000000000000')),
#  (2, 476, Decimal('5.3650000000000000')),
#  (2, 573, Decimal('5.3536363636363636')),
#  (1, 526, Decimal('5.3400000000000000')),
#  (2, 434, Decimal('5.3233333333333333')),
#  (1, 367, Decimal('5.3233333333333333')),
#  (1, 22, Decimal('5.3233333333333333')),
#  (1, 45, Decimal('5.3025000000000000')),
#  (2, 582, Decimal('5.2900000000000000')),
#  (1, 432, Decimal('5.2900000000000000')),
#  (2, 108, Decimal('5.2757142857142857')),
#  (2, 479, Decimal('5.2677777777777778')),
#  (1, 127, Decimal('5.2627272727272727')),
#  (2, 265, Decimal('5.2566666666666667')),
#  (2, 144, Decimal('5.2531578947368421')),
#  (1, 466, Decimal('5.2400000000000000')),
#  (1, 341, Decimal('5.2400000000000000')),
#  (2, 356, Decimal('5.2400000000000000')),
#  (1, 301, Decimal('5.2400000000000000')),
#  (2, 453, Decimal('5.2400000000000000')),
#  (1, 221, Decimal('5.2400000000000000')),
#  (2, 470, Decimal('5.2207692307692308')),
#  (1, 259, Decimal('5.2207692307692308')),
#  (2, 41, Decimal('5.2207692307692308')),
#  (1, 594, Decimal('5.2207692307692308')),
#  (2, 398, Decimal('5.2122222222222222')),
#  (1, 200, Decimal('5.2042857142857143')),
#  (1, 284, Decimal('5.2035714285714286')),
#  (2, 535, Decimal('5.1900000000000000')),
#  (1, 292, Decimal('5.1900000000000000')),
#  (1, 249, Decimal('5.1900000000000000')),
#  (1, 240, Decimal('5.1900000000000000')),
#  (1, 300, Decimal('5.1775000000000000')),
#  (1, 585, Decimal('5.1718181818181818')),
#  (1, 504, Decimal('5.1718181818181818')),
#  (1, 523, Decimal('5.1718181818181818')),
#  (2, 44, Decimal('5.1718181818181818')),
#  (1, 329, Decimal('5.1566666666666667')),
#  (2, 203, Decimal('5.1566666666666667')),
#  (2, 512, Decimal('5.1566666666666667')),
#  (1, 569, Decimal('5.1566666666666667')),
#  (1, 269, Decimal('5.1558333333333333')),
#  (2, 467, Decimal('5.1438461538461538')),
#  (2, 522, Decimal('5.1400000000000000')),
#  (2, 385, Decimal('5.1328571428571429')),
#  (2, 174, Decimal('5.1328571428571429')),
#  (1, 137, Decimal('5.1263636363636364')),
#  (1, 80, Decimal('5.1233333333333333')),
#  (2, 525, Decimal('5.1150000000000000')),
#  (2, 81, Decimal('5.1150000000000000')),
#  (1, 187, Decimal('5.1150000000000000')),
#  (2, 489, Decimal('5.1150000000000000')),
#  (2, 259, Decimal('5.1076470588235294')),
#  (1, 294, Decimal('5.1011111111111111')),
#  (2, 545, Decimal('5.1011111111111111')),
#  (2, 463, Decimal('5.1011111111111111')),
#  (1, 508, Decimal('5.1011111111111111')),
#  (1, 477, Decimal('5.1011111111111111')),
#  (1, 469, Decimal('5.0952631578947368')),
#  (1, 319, Decimal('5.0900000000000000')),
#  (2, 578, Decimal('5.0900000000000000')),
#  (1, 541, Decimal('5.0900000000000000')),
#  (1, 577, Decimal('5.0900000000000000')),
#  (2, 184, Decimal('5.0900000000000000')),
#  (2, 59, Decimal('5.0900000000000000')),
#  (2, 565, Decimal('5.0809090909090909')),
#  (1, 176, Decimal('5.0809090909090909')),
#  (2, 477, Decimal('5.0733333333333333')),
#  (2, 7, Decimal('5.0733333333333333')),
#  (2, 423, Decimal('5.0733333333333333')),
#  (1, 495, Decimal('5.0733333333333333')),
#  (1, 63, Decimal('5.0733333333333333')),
#  (1, 571, Decimal('5.0669230769230769')),
#  (1, 295, Decimal('5.0669230769230769')),
#  (1, 346, Decimal('5.0669230769230769')),
#  (1, 421, Decimal('5.0614285714285714')),
#  (2, 484, Decimal('5.0614285714285714')),
#  (2, 491, Decimal('5.0614285714285714')),
#  (2, 39, Decimal('5.0525000000000000')),
#  (1, 403, Decimal('5.0525000000000000')),
#  (1, 21, Decimal('5.0525000000000000')),
#  (2, 468, Decimal('5.0488235294117647')),
#  (2, 148, Decimal('5.0354545454545455')),
#  (2, 494, Decimal('4.9900000000000000')),
#  (1, 3, Decimal('4.9900000000000000')),
#  (2, 220, Decimal('4.9900000000000000')),
#  (1, 433, Decimal('4.9900000000000000')),
#  (1, 591, Decimal('4.9900000000000000')),
#  (1, 321, Decimal('4.9900000000000000')),
#  (2, 599, Decimal('4.9900000000000000')),
#  (2, 439, Decimal('4.9900000000000000')),
#  (1, 470, Decimal('4.9900000000000000')),
#  (1, 164, Decimal('4.9900000000000000')),
#  (1, 102, Decimal('4.9900000000000000')),
#  (2, 404, Decimal('4.9900000000000000')),
#  (1, 170, Decimal('4.9900000000000000')),
#  (1, 482, Decimal('4.9900000000000000')),
#  (2, 572, Decimal('4.9900000000000000')),
#  (1, 124, Decimal('4.9900000000000000')),
#  (1, 206, Decimal('4.9900000000000000')),
#  (1, 589, Decimal('4.9900000000000000')),
#  (2, 591, Decimal('4.9900000000000000')),
#  (2, 449, Decimal('4.9900000000000000')),
#  (1, 18, Decimal('4.9900000000000000')),
#  (1, 336, Decimal('4.9900000000000000')),
#  (1, 48, Decimal('4.9900000000000000')),
#  (1, 553, Decimal('4.9900000000000000')),
#  (2, 550, Decimal('4.9900000000000000')),
#  (2, 237, Decimal('4.9900000000000000')),
#  (1, 247, Decimal('4.9900000000000000')),
#  (2, 337, Decimal('4.9900000000000000')),
#  (2, 528, Decimal('4.9900000000000000')),
#  (1, 536, Decimal('4.9900000000000000')),
#  (2, 459, Decimal('4.9900000000000000')),
#  (1, 192, Decimal('4.9900000000000000')),
#  (1, 310, Decimal('4.9900000000000000')),
#  (2, 289, Decimal('4.9900000000000000')),
#  (2, 118, Decimal('4.9900000000000000')),
#  (1, 459, Decimal('4.9445454545454545')),
#  (2, 46, Decimal('4.9311764705882353')),
#  (2, 268, Decimal('4.9275000000000000')),
#  (2, 137, Decimal('4.9275000000000000')),
#  (2, 172, Decimal('4.9275000000000000')),
#  (2, 513, Decimal('4.9233333333333333')),
#  (1, 279, Decimal('4.9185714285714286')),
#  (1, 426, Decimal('4.9185714285714286')),
#  (1, 59, Decimal('4.9185714285714286')),
#  (1, 532, Decimal('4.9185714285714286')),
#  (1, 120, Decimal('4.9185714285714286')),
#  (1, 244, Decimal('4.9130769230769231')),
#  (1, 280, Decimal('4.9130769230769231')),
#  (2, 175, Decimal('4.9130769230769231')),
#  (1, 106, Decimal('4.9130769230769231')),
#  (1, 522, Decimal('4.9066666666666667')),
#  (1, 347, Decimal('4.9066666666666667')),
#  (1, 50, Decimal('4.9066666666666667')),
#  (1, 196, Decimal('4.9066666666666667')),
#  (2, 100, Decimal('4.9066666666666667')),
#  (2, 68, Decimal('4.9066666666666667')),
#  (1, 37, Decimal('4.8990909090909091')),
#  (2, 149, Decimal('4.8990909090909091')),
#  (1, 490, Decimal('4.8990909090909091')),
#  (2, 501, Decimal('4.8900000000000000')),
#  (2, 524, Decimal('4.8900000000000000')),
#  (1, 277, Decimal('4.8900000000000000')),
#  (2, 433, Decimal('4.8900000000000000')),
#  (1, 343, Decimal('4.8788888888888889')),
#  (1, 246, Decimal('4.8788888888888889')),
#  (1, 253, Decimal('4.8788888888888889')),
#  (2, 155, Decimal('4.8777777777777778')),
#  (2, 511, Decimal('4.8650000000000000')),
#  (2, 9, Decimal('4.8650000000000000')),
#  (2, 584, Decimal('4.8650000000000000')),
#  (1, 540, Decimal('4.8650000000000000')),
#  (2, 263, Decimal('4.8566666666666667')),
#  (2, 112, Decimal('4.8566666666666667')),
#  (2, 116, Decimal('4.8566666666666667')),
#  (1, 542, Decimal('4.8471428571428571')),
#  (1, 26, Decimal('4.8471428571428571')),
#  (1, 315, Decimal('4.8471428571428571')),
#  (1, 232, Decimal('4.8471428571428571')),
#  (2, 315, Decimal('4.8471428571428571')),
#  (1, 242, Decimal('4.8471428571428571')),
#  (2, 576, Decimal('4.8464285714285714')),
#  (2, 99, Decimal('4.8361538461538462')),
#  (1, 348, Decimal('4.8361538461538462')),
#  (1, 119, Decimal('4.8361538461538462')),
#  (2, 539, Decimal('4.8233333333333333')),
#  (1, 308, Decimal('4.8233333333333333')),
#  (2, 480, Decimal('4.8233333333333333')),
#  (1, 590, Decimal('4.8233333333333333')),
#  (1, 550, Decimal('4.8233333333333333')),
#  (1, 326, Decimal('4.8233333333333333')),
#  (2, 403, Decimal('4.8135294117647059')),
#  (2, 216, Decimal('4.8081818181818182')),
#  (1, 258, Decimal('4.8081818181818182')),
#  (2, 538, Decimal('4.8081818181818182')),
#  (2, 448, Decimal('4.8018750000000000')),
#  (1, 389, Decimal('4.7900000000000000')),
#  (1, 84, Decimal('4.7900000000000000')),
#  (2, 140, Decimal('4.7900000000000000')),
#  (2, 478, Decimal('4.7900000000000000')),
#  (2, 579, Decimal('4.7900000000000000')),
#  (2, 371, Decimal('4.7900000000000000')),
#  (2, 222, Decimal('4.7900000000000000')),
#  (2, 389, Decimal('4.7900000000000000')),
#  (2, 179, Decimal('4.7677777777777778')),
#  (2, 50, Decimal('4.7677777777777778')),
#  (2, 482, Decimal('4.7677777777777778')),
#  (2, 48, Decimal('4.7677777777777778')),
#  (2, 78, Decimal('4.7677777777777778')),
#  (2, 141, Decimal('4.7592307692307692')),
#  (2, 114, Decimal('4.7592307692307692')),
#  (2, 83, Decimal('4.7592307692307692')),
#  (2, 560, Decimal('4.7592307692307692')),
#  (2, 532, Decimal('4.7547058823529412')),
#  (2, 163, Decimal('4.7541176470588235')),
#  (1, 173, Decimal('4.7400000000000000')),
#  (1, 567, Decimal('4.7400000000000000')),
#  (2, 426, Decimal('4.7400000000000000')),
#  (2, 236, Decimal('4.7400000000000000')),
#  (1, 195, Decimal('4.7400000000000000')),
#  (2, 211, Decimal('4.7291304347826087')),
#  (1, 373, Decimal('4.7268421052631579')),
#  (2, 454, Decimal('4.7268421052631579')),
#  (2, 344, Decimal('4.7172727272727273')),
#  (2, 490, Decimal('4.7172727272727273')),
#  (2, 146, Decimal('4.7172727272727273')),
#  (2, 339, Decimal('4.7172727272727273')),
#  (1, 436, Decimal('4.7172727272727273')),
#  (1, 517, Decimal('4.7172727272727273')),
#  (2, 123, Decimal('4.7172727272727273')),
#  (2, 193, Decimal('4.7172727272727273')),
#  (2, 207, Decimal('4.7122222222222222')),
#  (2, 488, Decimal('4.7042857142857143')),
#  (2, 234, Decimal('4.7042857142857143')),
#  (2, 410, Decimal('4.7042857142857143')),
#  (1, 552, Decimal('4.7042857142857143')),
#  (1, 524, Decimal('4.7042857142857143')),
#  (1, 95, Decimal('4.7042857142857143')),
#  (1, 384, Decimal('4.7042857142857143')),
#  (2, 475, Decimal('4.7042857142857143')),
#  (1, 264, Decimal('4.6958823529411765')),
#  (2, 360, Decimal('4.6958823529411765')),
#  (2, 346, Decimal('4.6958823529411765')),
#  (2, 342, Decimal('4.6958823529411765')),
#  (2, 427, Decimal('4.6900000000000000')),
#  (2, 543, Decimal('4.6900000000000000')),
#  (1, 460, Decimal('4.6900000000000000')),
#  (2, 359, Decimal('4.6900000000000000')),
#  (1, 210, Decimal('4.6900000000000000')),
#  (2, 334, Decimal('4.6900000000000000')),
#  (2, 212, Decimal('4.6823076923076923')),
#  (2, 585, Decimal('4.6823076923076923')),
#  (1, 39, Decimal('4.6823076923076923')),
#  (2, 502, Decimal('4.6823076923076923')),
#  (1, 58, Decimal('4.6823076923076923')),
#  (1, 427, Decimal('4.6823076923076923')),
#  (1, 88, Decimal('4.6823076923076923')),
#  (2, 436, Decimal('4.6775000000000000')),
#  (1, 146, Decimal('4.6775000000000000')),
#  (1, 513, Decimal('4.6566666666666667')),
#  (2, 79, Decimal('4.6566666666666667')),
#  (1, 365, Decimal('4.6566666666666667')),
#  (1, 204, Decimal('4.6566666666666667')),
#  (2, 555, Decimal('4.6566666666666667')),
#  (1, 136, Decimal('4.6566666666666667')),
#  (2, 296, Decimal('4.6566666666666667')),
#  (1, 375, Decimal('4.6566666666666667')),
#  (2, 400, Decimal('4.6566666666666667')),
#  (2, 390, Decimal('4.6566666666666667')),
#  (2, 497, Decimal('4.6566666666666667')),
#  (1, 462, Decimal('4.6566666666666667')),
#  (2, 571, Decimal('4.6566666666666667')),
#  (2, 57, Decimal('4.6566666666666667')),
#  (2, 286, Decimal('4.6566666666666667')),
#  (2, 347, Decimal('4.6566666666666667')),
#  (1, 416, Decimal('4.6370588235294118')),
#  (1, 180, Decimal('4.6328571428571429')),
#  (2, 201, Decimal('4.6328571428571429')),
#  (1, 379, Decimal('4.6328571428571429')),
#  (2, 170, Decimal('4.6328571428571429')),
#  (2, 368, Decimal('4.6328571428571429')),
#  (1, 448, Decimal('4.6272727272727273')),
#  (1, 70, Decimal('4.6263636363636364')),
#  (1, 219, Decimal('4.6263636363636364')),
#  (2, 526, Decimal('4.6263636363636364')),
#  (2, 460, Decimal('4.6263636363636364')),
#  (1, 489, Decimal('4.6263636363636364')),
#  (2, 301, Decimal('4.6263636363636364')),
#  (2, 262, Decimal('4.6263636363636364')),
#  (2, 154, Decimal('4.6263636363636364')),
#  (2, 547, Decimal('4.6263636363636364')),
#  (2, 24, Decimal('4.6263636363636364')),
#  (2, 122, Decimal('4.6150000000000000')),
#  (2, 540, Decimal('4.6150000000000000')),
#  (1, 166, Decimal('4.6053846153846154')),
#  (2, 437, Decimal('4.6053846153846154')),
#  (1, 185, Decimal('4.6053846153846154')),
#  (1, 140, Decimal('4.6053846153846154')),
#  (1, 445, Decimal('4.6053846153846154')),
#  (2, 109, Decimal('4.6053846153846154')),
#  (2, 362, Decimal('4.6053846153846154')),
#  (2, 150, Decimal('4.6053846153846154')),
#  (1, 533, Decimal('4.6011111111111111')),
#  (2, 181, Decimal('4.6011111111111111')),
#  (2, 86, Decimal('4.6011111111111111')),
#  (1, 76, Decimal('4.5900000000000000')),
#  (2, 153, Decimal('4.5900000000000000')),
#  (2, 238, Decimal('4.5900000000000000')),
#  (1, 55, Decimal('4.5900000000000000')),
#  (2, 250, Decimal('4.5900000000000000')),
#  (1, 412, Decimal('4.5900000000000000')),
#  (2, 279, Decimal('4.5900000000000000')),
#  (2, 293, Decimal('4.5900000000000000')),
#  (2, 575, Decimal('4.5900000000000000')),
#  (1, 179, Decimal('4.5782352941176471')),
#  (2, 587, Decimal('4.5782352941176471')),
#  (2, 473, Decimal('4.5689473684210526')),
#  (2, 274, Decimal('4.5614285714285714')),
#  (2, 61, Decimal('4.5614285714285714')),
#  (2, 496, Decimal('4.5614285714285714')),
#  (1, 5, Decimal('4.5614285714285714')),
#  (1, 417, Decimal('4.5614285714285714')),
#  (1, 238, Decimal('4.5614285714285714')),
#  (1, 414, Decimal('4.5614285714285714')),
#  (1, 519, Decimal('4.5614285714285714')),
#  (2, 589, Decimal('4.5614285714285714')),
#  (2, 379, Decimal('4.5614285714285714')),
#  (1, 86, Decimal('4.5614285714285714')),
#  (1, 390, Decimal('4.5525000000000000')),
#  (1, 71, Decimal('4.5525000000000000')),
#  (2, 31, Decimal('4.5525000000000000')),
#  (1, 499, Decimal('4.5525000000000000')),
#  (2, 218, Decimal('4.5455555555555556')),
#  (1, 322, Decimal('4.5455555555555556')),
#  (2, 443, Decimal('4.5455555555555556')),
#  (1, 486, Decimal('4.5455555555555556')),
#  (1, 562, Decimal('4.5455555555555556')),
#  (1, 575, Decimal('4.5455555555555556')),
#  (1, 491, Decimal('4.5354545454545455')),
#  (1, 583, Decimal('4.5354545454545455')),
#  (2, 367, Decimal('4.5354545454545455')),
#  (1, 593, Decimal('4.5354545454545455')),
#  (2, 165, Decimal('4.5354545454545455')),
#  (2, 409, Decimal('4.5354545454545455')),
#  (1, 580, Decimal('4.5284615384615385')),
#  (2, 82, Decimal('4.5284615384615385')),
#  (2, 519, Decimal('4.5233333333333333')),
#  (2, 251, Decimal('4.5233333333333333')),
#  (1, 467, Decimal('4.5233333333333333')),
#  (1, 33, Decimal('4.5233333333333333')),
#  (1, 54, Decimal('4.5233333333333333')),
#  (2, 206, Decimal('4.5194117647058824')),
#  (1, 13, Decimal('4.5194117647058824')),
#  (2, 284, Decimal('4.4912500000000000')),
#  (1, 169, Decimal('4.4900000000000000')),
#  (2, 200, Decimal('4.4900000000000000')),
#  (1, 324, Decimal('4.4900000000000000')),
#  (1, 430, Decimal('4.4900000000000000')),
#  (1, 198, Decimal('4.4900000000000000')),
#  (1, 149, Decimal('4.4900000000000000')),
#  (2, 343, Decimal('4.4900000000000000')),
#  (1, 362, Decimal('4.4900000000000000')),
#  (1, 398, Decimal('4.4900000000000000')),
#  (2, 10, Decimal('4.4900000000000000')),
#  (1, 291, Decimal('4.4900000000000000')),
#  (2, 338, Decimal('4.4900000000000000')),
#  (1, 44, Decimal('4.4900000000000000')),
#  (1, 318, Decimal('4.4900000000000000')),
#  (1, 406, Decimal('4.4900000000000000')),
#  (1, 217, Decimal('4.4900000000000000')),
#  (1, 472, Decimal('4.4900000000000000')),
#  (2, 89, Decimal('4.4900000000000000')),
#  (2, 255, Decimal('4.4900000000000000')),
#  (1, 11, Decimal('4.4900000000000000')),
#  (1, 325, Decimal('4.4900000000000000')),
#  (2, 510, Decimal('4.4900000000000000')),
#  (1, 193, Decimal('4.4900000000000000')),
#  (1, 352, Decimal('4.4900000000000000')),
#  (1, 131, Decimal('4.4900000000000000')),
#  (1, 287, Decimal('4.4900000000000000')),
#  (2, 257, Decimal('4.4636842105263158')),
#  (2, 506, Decimal('4.4605882352941176')),
#  (2, 373, Decimal('4.4566666666666667')),
#  (1, 226, Decimal('4.4566666666666667')),
#  (1, 209, Decimal('4.4566666666666667')),
#  (2, 258, Decimal('4.4515384615384615')),
#  (1, 484, Decimal('4.4515384615384615')),
#  (2, 98, Decimal('4.4515384615384615')),
#  (1, 56, Decimal('4.4515384615384615')),
#  (2, 588, Decimal('4.4515384615384615')),
#  (2, 56, Decimal('4.4515384615384615')),
#  (1, 441, Decimal('4.4445454545454545')),
#  (1, 438, Decimal('4.4445454545454545')),
#  (1, 453, Decimal('4.4445454545454545')),
#  (2, 199, Decimal('4.4445454545454545')),
#  (2, 202, Decimal('4.4445454545454545')),
#  (2, 520, Decimal('4.4445454545454545')),
#  (1, 422, Decimal('4.4445454545454545')),
#  (2, 195, Decimal('4.4445454545454545')),
#  (1, 107, Decimal('4.4445454545454545')),
#  (1, 235, Decimal('4.4445454545454545')),
#  (1, 510, Decimal('4.4344444444444444')),
#  (2, 314, Decimal('4.4344444444444444')),
#  (2, 93, Decimal('4.4344444444444444')),
#  (2, 566, Decimal('4.4275000000000000')),
#  (2, 363, Decimal('4.4275000000000000')),
#  (1, 592, Decimal('4.4275000000000000')),
#  (2, 518, Decimal('4.4185714285714286')),
#  (1, 449, Decimal('4.4185714285714286')),
#  (2, 166, Decimal('4.4185714285714286')),
#  (2, 341, Decimal('4.4185714285714286')),
#  (1, 212, Decimal('4.4185714285714286')),
#  (1, 447, Decimal('4.4185714285714286')),
#  (1, 493, Decimal('4.4185714285714286')),
#  (2, 364, Decimal('4.4066666666666667')),
#  (2, 452, Decimal('4.4066666666666667')),
#  (1, 443, Decimal('4.4066666666666667')),
#  (2, 345, Decimal('4.4066666666666667')),
#  (2, 431, Decimal('4.4066666666666667')),
#  (2, 500, Decimal('4.4066666666666667')),
#  (2, 386, Decimal('4.4066666666666667')),
#  (1, 368, Decimal('4.4017647058823529')),
#  (1, 229, Decimal('4.3900000000000000')),
#  (2, 121, Decimal('4.3900000000000000')),
#  (1, 497, Decimal('4.3900000000000000')),
#  (1, 266, Decimal('4.3900000000000000')),
#  (1, 27, Decimal('4.3900000000000000')),
#  (1, 528, Decimal('4.3900000000000000')),
#  (1, 598, Decimal('4.3900000000000000')),
#  (2, 210, Decimal('4.3900000000000000')),
#  (2, 110, Decimal('4.3900000000000000')),
#  (1, 312, Decimal('4.3900000000000000')),
#  (2, 51, Decimal('4.3900000000000000')),
#  (1, 382, Decimal('4.3900000000000000')),
#  (1, 465, Decimal('4.3900000000000000')),
#  (1, 366, Decimal('4.3900000000000000')),
#  (2, 231, Decimal('4.3900000000000000')),
#  (2, 332, Decimal('4.3900000000000000')),
#  (1, 148, Decimal('4.3813043478260870')),
#  (1, 404, Decimal('4.3788888888888889')),
#  (1, 32, Decimal('4.3746153846153846')),
#  (2, 552, Decimal('4.3746153846153846')),
#  (1, 554, Decimal('4.3746153846153846')),
#  (2, 562, Decimal('4.3746153846153846')),
#  (1, 112, Decimal('4.3746153846153846')),
#  (2, 418, Decimal('4.3746153846153846')),
#  (2, 267, Decimal('4.3650000000000000')),
#  (2, 105, Decimal('4.3650000000000000')),
#  (2, 536, Decimal('4.3650000000000000')),
#  (1, 7, Decimal('4.3650000000000000')),
#  (1, 331, Decimal('4.3650000000000000')),
#  (1, 223, Decimal('4.3650000000000000')),
#  (1, 66, Decimal('4.3584210526315789')),
#  (2, 62, Decimal('4.3536363636363636')),
#  (2, 135, Decimal('4.3536363636363636')),
#  (2, 127, Decimal('4.3536363636363636')),
#  (1, 424, Decimal('4.3536363636363636')),
#  (1, 296, Decimal('4.3536363636363636')),
#  (1, 428, Decimal('4.3536363636363636')),
#  (1, 409, Decimal('4.3536363636363636')),
#  (2, 96, Decimal('4.3536363636363636')),
#  (2, 537, Decimal('4.3536363636363636')),
#  (2, 266, Decimal('4.3536363636363636')),
#  (1, 506, Decimal('4.3536363636363636')),
#  (2, 504, Decimal('4.3471428571428571')),
#  (2, 113, Decimal('4.3471428571428571')),
#  (2, 306, Decimal('4.3471428571428571')),
#  (1, 125, Decimal('4.3400000000000000')),
#  (1, 337, Decimal('4.3233333333333333')),
#  (1, 478, Decimal('4.3233333333333333')),
#  (2, 158, Decimal('4.3233333333333333')),
#  (1, 475, Decimal('4.3233333333333333')),
#  (2, 531, Decimal('4.3233333333333333')),
#  (2, 327, Decimal('4.3233333333333333')),
#  (1, 360, Decimal('4.3233333333333333')),
#  (2, 551, Decimal('4.3233333333333333')),
#  (1, 61, Decimal('4.3233333333333333')),
#  (1, 115, Decimal('4.3233333333333333')),
#  (2, 55, Decimal('4.3233333333333333')),
#  (1, 354, Decimal('4.3057894736842105')),
#  (1, 307, Decimal('4.3025000000000000')),
#  (1, 245, Decimal('4.3025000000000000')),
#  (1, 189, Decimal('4.2976923076923077')),
#  (2, 392, Decimal('4.2976923076923077')),
#  (1, 78, Decimal('4.2976923076923077')),
#  (2, 32, Decimal('4.2976923076923077')),
#  (2, 285, Decimal('4.2900000000000000')),
#  (1, 298, Decimal('4.2900000000000000')),
#  (2, 261, Decimal('4.2900000000000000')),
#  (2, 316, Decimal('4.2900000000000000')),
#  (2, 178, Decimal('4.2900000000000000')),
#  (1, 94, Decimal('4.2900000000000000')),
#  (2, 377, Decimal('4.2900000000000000')),
#  (1, 267, Decimal('4.2841176470588235')),
#  (2, 253, Decimal('4.2841176470588235')),
#  (1, 168, Decimal('4.2841176470588235')),
#  (1, 15, Decimal('4.2835294117647059')),
#  (1, 582, Decimal('4.2757142857142857')),
#  (2, 486, Decimal('4.2757142857142857')),
#  (1, 423, Decimal('4.2757142857142857')),
#  (2, 277, Decimal('4.2757142857142857')),
#  (1, 139, Decimal('4.2757142857142857')),
#  (2, 376, Decimal('4.2757142857142857')),
#  (2, 294, Decimal('4.2757142857142857')),
#  (1, 144, Decimal('4.2757142857142857')),
#  (2, 119, Decimal('4.2677777777777778')),
#  (2, 399, Decimal('4.2627272727272727')),
#  (1, 518, Decimal('4.2627272727272727')),
#  (2, 421, Decimal('4.2627272727272727')),
#  (1, 529, Decimal('4.2627272727272727')),
#  (2, 54, Decimal('4.2627272727272727')),
#  (1, 393, Decimal('4.2627272727272727')),
#  (1, 440, Decimal('4.2627272727272727')),
#  (2, 291, Decimal('4.2627272727272727')),
#  (2, 34, Decimal('4.2627272727272727')),
#  (2, 43, Decimal('4.2618181818181818')),
#  (1, 471, Decimal('4.2566666666666667')),
#  (1, 456, Decimal('4.2566666666666667')),
#  (2, 564, Decimal('4.2566666666666667')),
#  (1, 297, Decimal('4.2566666666666667')),
#  (1, 73, Decimal('4.2400000000000000')),
#  (2, 352, Decimal('4.2400000000000000')),
#  (1, 410, Decimal('4.2400000000000000')),
#  (2, 171, Decimal('4.2400000000000000')),
#  (1, 143, Decimal('4.2400000000000000')),
#  (1, 233, Decimal('4.2400000000000000')),
#  (2, 590, Decimal('4.2400000000000000')),
#  (2, 304, Decimal('4.2400000000000000')),
#  (1, 41, Decimal('4.2400000000000000')),
#  (1, 496, Decimal('4.2400000000000000')),
#  (1, 333, Decimal('4.2400000000000000')),
#  (1, 560, Decimal('4.2400000000000000')),
#  (2, 169, Decimal('4.2400000000000000')),
#  (1, 90, Decimal('4.2400000000000000')),
#  (1, 49, Decimal('4.2400000000000000')),
#  (2, 20, Decimal('4.2400000000000000')),
#  (1, 117, Decimal('4.2400000000000000')),
#  (2, 563, Decimal('4.2252941176470588')),
#  (2, 214, Decimal('4.2252941176470588')),
#  (1, 160, Decimal('4.2207692307692308')),
#  (2, 240, Decimal('4.2207692307692308')),
#  (2, 276, Decimal('4.2207692307692308')),
#  (1, 35, Decimal('4.2172727272727273')),
#  (1, 388, Decimal('4.2122222222222222')),
#  (1, 501, Decimal('4.2122222222222222')),
#  (1, 316, Decimal('4.2122222222222222')),
#  (2, 597, Decimal('4.2122222222222222')),
#  (2, 492, Decimal('4.2122222222222222')),
#  (2, 190, Decimal('4.2042857142857143')),
#  (1, 306, Decimal('4.2042857142857143')),
#  (2, 570, Decimal('4.2042857142857143')),
#  (2, 451, Decimal('4.2042857142857143')),
#  (2, 457, Decimal('4.1910000000000000')),
#  (1, 155, Decimal('4.1906666666666667')),
#  (1, 87, Decimal('4.1900000000000000')),
#  (2, 324, Decimal('4.1900000000000000')),
#  (2, 197, Decimal('4.1900000000000000')),
#  (2, 33, Decimal('4.1900000000000000')),
#  (2, 546, Decimal('4.1900000000000000')),
#  (2, 29, Decimal('4.1900000000000000')),
#  (1, 595, Decimal('4.1775000000000000')),
#  (1, 304, Decimal('4.1718181818181818')),
#  (2, 130, Decimal('4.1718181818181818')),
#  (1, 380, Decimal('4.1718181818181818')),
#  (2, 11, Decimal('4.1718181818181818')),
#  (1, 197, Decimal('4.1664705882352941')),
#  (1, 349, Decimal('4.1664705882352941')),
#  (2, 495, Decimal('4.1566666666666667')),
#  (2, 126, Decimal('4.1566666666666667')),
#  (1, 492, Decimal('4.1566666666666667')),
#  (1, 4, Decimal('4.1566666666666667')),
#  (2, 533, Decimal('4.1566666666666667')),
#  (1, 111, Decimal('4.1566666666666667')),
#  (1, 152, Decimal('4.1566666666666667')),
#  (2, 465, Decimal('4.1566666666666667')),
#  (2, 70, Decimal('4.1566666666666667')),
#  (2, 425, Decimal('4.1566666666666667')),
#  (2, 396, Decimal('4.1478947368421053')),
#  (1, 69, Decimal('4.1438461538461538')),
#  (2, 239, Decimal('4.1438461538461538')),
#  (1, 40, Decimal('4.1438461538461538')),
#  (2, 415, Decimal('4.1438461538461538')),
#  (2, 77, Decimal('4.1438461538461538')),
#  (1, 265, Decimal('4.1438461538461538')),
#  (2, 139, Decimal('4.1438461538461538')),
#  (1, 454, Decimal('4.1438461538461538')),
#  (2, 407, Decimal('4.1438461538461538')),
#  (1, 8, Decimal('4.1328571428571429')),
#  (2, 485, Decimal('4.1328571428571429')),
#  (2, 225, Decimal('4.1328571428571429')),
#  (1, 161, Decimal('4.1328571428571429')),
#  (2, 596, Decimal('4.1328571428571429')),
#  (2, 402, Decimal('4.1328571428571429')),
#  (2, 412, Decimal('4.1328571428571429')),
#  (2, 15, Decimal('4.1240000000000000')),
#  (2, 213, Decimal('4.1233333333333333')),
#  (1, 317, Decimal('4.1233333333333333')),
#  (1, 89, Decimal('4.1233333333333333')),
#  (1, 334, Decimal('4.1233333333333333')),
#  (1, 548, Decimal('4.1150000000000000')),
#  (2, 270, Decimal('4.1150000000000000')),
#  (2, 375, Decimal('4.1150000000000000')),
#  (2, 374, Decimal('4.1150000000000000')),
#  (2, 120, Decimal('4.1150000000000000')),
#  (2, 143, Decimal('4.1150000000000000')),
#  (1, 555, Decimal('4.1150000000000000')),
#  (2, 444, Decimal('4.1150000000000000')),
#  (2, 60, Decimal('4.1150000000000000')),
#  (2, 378, Decimal('4.1150000000000000')),
#  (2, 21, Decimal('4.1150000000000000')),
#  (1, 559, Decimal('4.1076470588235294')),
#  (1, 502, Decimal('4.1076470588235294')),
#  (1, 194, Decimal('4.1011111111111111')),
#  (1, 303, Decimal('4.1011111111111111')),
#  (2, 365, Decimal('4.1011111111111111')),
#  (2, 249, Decimal('4.1011111111111111')),
#  (1, 547, Decimal('4.1011111111111111')),
#  (1, 171, Decimal('4.1011111111111111')),
#  (2, 322, Decimal('4.0900000000000000')),
#  (2, 556, Decimal('4.0900000000000000')),
#  (2, 509, Decimal('4.0900000000000000')),
#  (2, 300, Decimal('4.0900000000000000')),
#  (2, 159, Decimal('4.0900000000000000')),
#  (2, 594, Decimal('4.0900000000000000')),
#  (1, 36, Decimal('4.0900000000000000')),
#  (2, 432, Decimal('4.0900000000000000')),
#  (1, 98, Decimal('4.0809090909090909')),
#  (2, 549, Decimal('4.0809090909090909')),
#  (2, 58, Decimal('4.0809090909090909')),
#  (2, 323, Decimal('4.0809090909090909')),
#  (1, 505, Decimal('4.0809090909090909')),
#  (2, 26, Decimal('4.0809090909090909')),
#  (2, 351, Decimal('4.0809090909090909')),
#  (1, 578, Decimal('4.0809090909090909')),
#  (2, 125, Decimal('4.0809090909090909')),
#  (2, 313, Decimal('4.0809090909090909')),
#  (1, 581, Decimal('4.0733333333333333')),
#  (1, 299, Decimal('4.0733333333333333')),
#  (1, 213, Decimal('4.0733333333333333')),
#  (1, 128, Decimal('4.0733333333333333')),
#  (1, 397, Decimal('4.0733333333333333')),
#  (1, 126, Decimal('4.0669230769230769')),
#  (2, 282, Decimal('4.0669230769230769')),
#  (2, 553, Decimal('4.0669230769230769')),
#  (1, 274, Decimal('4.0669230769230769')),
#  (2, 66, Decimal('4.0614285714285714')),
#  (1, 481, Decimal('4.0614285714285714')),
#  (2, 156, Decimal('4.0614285714285714')),
#  (1, 1, Decimal('4.0566666666666667')),
#  (2, 242, Decimal('4.0566666666666667')),
#  (2, 80, Decimal('4.0566666666666667')),
#  (2, 129, Decimal('4.0525000000000000')),
#  (2, 204, Decimal('4.0525000000000000')),
#  (2, 529, Decimal('4.0488235294117647')),
#  (1, 468, Decimal('4.0488235294117647')),
#  (2, 145, Decimal('4.0455555555555556')),
#  (2, 388, Decimal('4.0426315789473684')),
#  (2, 84, Decimal('4.0400000000000000')),
#  (1, 574, Decimal('4.0376190476190476')),
#  (1, 53, Decimal('3.9907692307692308')),
#  (2, 593, Decimal('3.9900000000000000')),
#  (2, 247, Decimal('3.9900000000000000')),
#  (1, 261, Decimal('3.9900000000000000')),
#  (2, 221, Decimal('3.9900000000000000')),
#  (1, 110, Decimal('3.9900000000000000')),
#  (2, 215, Decimal('3.9900000000000000')),
#  (1, 383, Decimal('3.9900000000000000')),
#  (1, 23, Decimal('3.9900000000000000')),
#  (2, 63, Decimal('3.9900000000000000')),
#  (2, 567, Decimal('3.9900000000000000')),
#  (2, 394, Decimal('3.9900000000000000')),
#  (2, 95, Decimal('3.9900000000000000')),
#  (1, 400, Decimal('3.9900000000000000')),
#  (1, 51, Decimal('3.9900000000000000')),
#  (2, 299, Decimal('3.9900000000000000')),
#  (2, 353, Decimal('3.9900000000000000')),
#  (2, 106, Decimal('3.9900000000000000')),
#  (2, 40, Decimal('3.9900000000000000')),
#  (1, 276, Decimal('3.9900000000000000')),
#  (1, 402, Decimal('3.9900000000000000')),
#  (1, 105, Decimal('3.9900000000000000')),
#  (2, 45, Decimal('3.9900000000000000')),
#  (1, 371, Decimal('3.9900000000000000')),
#  (1, 376, Decimal('3.9900000000000000')),
#  (2, 12, Decimal('3.9900000000000000')),
#  (1, 47, Decimal('3.9900000000000000')),
#  (2, 333, Decimal('3.9900000000000000')),
#  (1, 222, Decimal('3.9900000000000000')),
#  (1, 556, Decimal('3.9900000000000000')),
#  (2, 271, Decimal('3.9900000000000000')),
#  (1, 455, Decimal('3.9900000000000000')),
#  (2, 280, Decimal('3.9900000000000000')),
#  (1, 446, Decimal('3.9900000000000000')),
#  (2, 295, Decimal('3.9900000000000000')),
#  (1, 2, Decimal('3.9900000000000000')),
#  (1, 182, Decimal('3.9900000000000000')),
#  (2, 101, Decimal('3.9900000000000000')),
#  (1, 370, Decimal('3.9900000000000000')),
#  (2, 136, Decimal('3.9900000000000000')),
#  (1, 431, Decimal('3.9900000000000000')),
#  (1, 256, Decimal('3.9900000000000000')),
#  (1, 60, Decimal('3.9900000000000000')),
#  (2, 420, Decimal('3.9900000000000000')),
#  (1, 260, Decimal('3.9900000000000000')),
#  (2, 574, Decimal('3.9900000000000000')),
#  (1, 81, Decimal('3.9900000000000000')),
#  (2, 328, Decimal('3.9900000000000000')),
#  (2, 189, Decimal('3.9900000000000000')),
#  (1, 157, Decimal('3.9900000000000000')),
#  (1, 262, Decimal('3.9900000000000000')),
#  (1, 190, Decimal('3.9900000000000000')),
#  (2, 176, Decimal('3.9900000000000000')),
#  (1, 75, Decimal('3.9428571428571429')),
#  (1, 520, Decimal('3.9400000000000000')),
#  (2, 147, Decimal('3.9400000000000000')),
#  (1, 535, Decimal('3.9344444444444444')),
#  (1, 25, Decimal('3.9311764705882353')),
#  (1, 132, Decimal('3.9275000000000000')),
#  (1, 451, Decimal('3.9275000000000000')),
#  (1, 565, Decimal('3.9275000000000000')),
#  (1, 42, Decimal('3.9275000000000000')),
#  (1, 498, Decimal('3.9275000000000000')),
#  (2, 74, Decimal('3.9275000000000000')),
#  (2, 23, Decimal('3.9275000000000000')),
#  (2, 336, Decimal('3.9233333333333333')),
#  (1, 172, Decimal('3.9185714285714286')),
#  (1, 485, Decimal('3.9185714285714286')),
#  (1, 537, Decimal('3.9130769230769231')),
#  (1, 151, Decimal('3.9130769230769231')),
#  (1, 113, Decimal('3.9130769230769231')),
#  (1, 407, Decimal('3.9130769230769231')),
#  (1, 544, Decimal('3.9130769230769231')),
#  (1, 147, Decimal('3.9066666666666667')),
#  (2, 507, Decimal('3.9066666666666667')),
#  (1, 43, Decimal('3.9000000000000000')),
#  (1, 191, Decimal('3.8990909090909091')),
#  (1, 100, Decimal('3.8990909090909091')),
#  (2, 319, Decimal('3.8990909090909091')),
#  (2, 471, Decimal('3.8990909090909091')),
#  (1, 434, Decimal('3.8990909090909091')),
#  (1, 507, Decimal('3.8990909090909091')),
#  (1, 270, Decimal('3.8990909090909091')),
#  (2, 369, Decimal('3.8990909090909091')),
#  (2, 348, Decimal('3.8947619047619048')),
#  (2, 474, Decimal('3.8900000000000000')),
#  (2, 97, Decimal('3.8900000000000000')),
#  (1, 227, Decimal('3.8900000000000000')),
#  (1, 121, Decimal('3.8900000000000000')),
#  (1, 545, Decimal('3.8900000000000000')),
#  (2, 466, Decimal('3.8900000000000000')),
#  (2, 73, Decimal('3.8900000000000000')),
#  (2, 516, Decimal('3.8900000000000000')),
#  (2, 269, Decimal('3.8800000000000000')),
#  (2, 104, Decimal('3.8788888888888889')),
#  (2, 65, Decimal('3.8788888888888889')),
#  (1, 183, Decimal('3.8788888888888889')),
#  (1, 145, Decimal('3.8788888888888889')),
#  (1, 83, Decimal('3.8788888888888889')),
#  (2, 317, Decimal('3.8788888888888889')),
#  (1, 415, Decimal('3.8788888888888889')),
#  (1, 150, Decimal('3.8788888888888889')),
#  (2, 128, Decimal('3.8788888888888889')),
#  (2, 164, Decimal('3.8788888888888889')),
#  (2, 102, Decimal('3.8788888888888889')),
#  (2, 107, Decimal('3.8723529411764706')),
#  (1, 186, Decimal('3.8650000000000000')),
#  (2, 408, Decimal('3.8650000000000000')),
#  (2, 548, Decimal('3.8650000000000000')),
#  (2, 469, Decimal('3.8650000000000000')),
#  (2, 180, Decimal('3.8650000000000000')),
#  (1, 38, Decimal('3.8650000000000000')),
#  (2, 446, Decimal('3.8650000000000000')),
#  (2, 256, Decimal('3.8566666666666667')),
#  (1, 257, Decimal('3.8566666666666667')),
#  (2, 52, Decimal('3.8566666666666667')),
#  (2, 27, Decimal('3.8566666666666667')),
#  (1, 512, Decimal('3.8471428571428571')),
#  (2, 248, Decimal('3.8471428571428571')),
#  (1, 282, Decimal('3.8471428571428571')),
#  (1, 399, Decimal('3.8471428571428571')),
#  (1, 396, Decimal('3.8471428571428571')),
#  (1, 511, Decimal('3.8471428571428571')),
#  (1, 516, Decimal('3.8471428571428571')),
#  (2, 18, Decimal('3.8471428571428571')),
#  (2, 305, Decimal('3.8361538461538462')),
#  (1, 230, Decimal('3.8361538461538462')),
#  (1, 419, Decimal('3.8361538461538462')),
#  (2, 186, Decimal('3.8361538461538462')),
#  (2, 273, Decimal('3.8361538461538462')),
#  (1, 28, Decimal('3.8361538461538462')),
#  (2, 515, Decimal('3.8321052631578947')),
#  (2, 438, Decimal('3.8321052631578947')),
#  (2, 230, Decimal('3.8233333333333333')),
#  (2, 393, Decimal('3.8233333333333333')),
#  (2, 325, Decimal('3.8233333333333333')),
#  (2, 534, Decimal('3.8233333333333333')),
#  (2, 281, Decimal('3.8233333333333333')),
#  (1, 123, Decimal('3.8233333333333333')),
#  (1, 174, Decimal('3.8233333333333333')),
#  (1, 114, Decimal('3.8135294117647059')),
#  (1, 457, Decimal('3.8129411764705882')),
#  (2, 350, Decimal('3.8081818181818182')),
#  (1, 332, Decimal('3.8081818181818182')),
#  (1, 130, Decimal('3.8081818181818182')),
#  (2, 320, Decimal('3.8081818181818182')),
#  (2, 217, Decimal('3.8081818181818182')),
#  (1, 408, Decimal('3.8081818181818182')),
#  (1, 328, Decimal('3.8081818181818182')),
#  (2, 577, Decimal('3.8025000000000000')),
#  (1, 429, Decimal('3.7900000000000000')),
#  (2, 192, Decimal('3.7900000000000000')),
#  (1, 378, Decimal('3.7900000000000000')),
#  (1, 29, Decimal('3.7900000000000000')),
#  (2, 358, Decimal('3.7900000000000000')),
#  (1, 358, Decimal('3.7900000000000000')),
#  (2, 455, Decimal('3.7900000000000000')),
#  (2, 142, Decimal('3.7900000000000000')),
#  (1, 394, Decimal('3.7900000000000000')),
#  (2, 117, Decimal('3.7900000000000000')),
#  (2, 37, Decimal('3.7900000000000000')),
#  (2, 168, Decimal('3.7900000000000000')),
#  (1, 211, Decimal('3.7900000000000000')),
#  (1, 313, Decimal('3.7900000000000000')),
#  (2, 25, Decimal('3.7900000000000000')),
#  (1, 236, Decimal('3.7794736842105263')),
#  (2, 487, Decimal('3.7757142857142857')),
#  (2, 481, Decimal('3.7757142857142857')),
#  (1, 108, Decimal('3.7757142857142857')),
#  (1, 546, Decimal('3.7757142857142857')),
#  (1, 92, Decimal('3.7757142857142857')),
#  (1, 576, Decimal('3.7683333333333333')),
#  (2, 413, Decimal('3.7677777777777778')),
#  (1, 275, Decimal('3.7677777777777778')),
#  (2, 517, Decimal('3.7592307692307692')),
#  (1, 327, Decimal('3.7592307692307692')),
#  (2, 581, Decimal('3.7592307692307692')),
#  (2, 458, Decimal('3.7592307692307692')),
#  (1, 52, Decimal('3.7592307692307692')),
#  (2, 167, Decimal('3.7592307692307692')),
#  (1, 425, Decimal('3.7592307692307692')),
#  (2, 387, Decimal('3.7592307692307692')),
#  (2, 208, Decimal('3.7592307692307692')),
#  (2, 42, Decimal('3.7592307692307692')),
#  (2, 228, Decimal('3.7584615384615385')),
#  (1, 527, Decimal('3.7547058823529412')),
#  (2, 72, Decimal('3.7400000000000000')),
#  (2, 405, Decimal('3.7400000000000000')),
#  (1, 566, Decimal('3.7400000000000000')),
#  (2, 90, Decimal('3.7400000000000000')),
#  (1, 335, Decimal('3.7400000000000000')),
#  (2, 541, Decimal('3.7400000000000000')),
#  (1, 476, Decimal('3.7400000000000000')),
#  (2, 22, Decimal('3.7400000000000000')),
#  (1, 272, Decimal('3.7400000000000000')),
#  (1, 167, Decimal('3.7400000000000000')),
#  (1, 154, Decimal('3.7400000000000000')),
#  (1, 488, Decimal('3.7400000000000000')),
#  (1, 340, Decimal('3.7400000000000000')),
#  (2, 243, Decimal('3.7400000000000000')),
#  (2, 401, Decimal('3.7400000000000000')),
#  (1, 572, Decimal('3.7233333333333333')),
#  (1, 494, Decimal('3.7172727272727273')),
#  (2, 559, Decimal('3.7172727272727273')),
#  (1, 234, Decimal('3.7172727272727273')),
#  (2, 290, Decimal('3.7172727272727273')),
#  (2, 188, Decimal('3.7122222222222222')),
#  (1, 30, Decimal('3.7122222222222222')),
#  (2, 75, Decimal('3.7116666666666667')),
#  (2, 442, Decimal('3.7042857142857143')),
#  (1, 203, Decimal('3.7042857142857143')),
#  (1, 480, Decimal('3.7042857142857143')),
#  (1, 188, Decimal('3.7042857142857143')),
#  (1, 437, Decimal('3.7042857142857143')),
#  (2, 160, Decimal('3.7042857142857143')),
#  (2, 557, Decimal('3.6900000000000000')),
#  (1, 355, Decimal('3.6900000000000000')),
#  (2, 440, Decimal('3.6900000000000000')),
#  (2, 182, Decimal('3.6900000000000000')),
#  (2, 161, Decimal('3.6900000000000000')),
#  (1, 364, Decimal('3.6900000000000000')),
#  (2, 224, Decimal('3.6900000000000000')),
#  (2, 499, Decimal('3.6823076923076923')),
#  (2, 447, Decimal('3.6823076923076923')),
#  (2, 275, Decimal('3.6775000000000000')),
#  (2, 441, Decimal('3.6775000000000000')),
#  (2, 111, Decimal('3.6742105263157895')),
#  (2, 196, Decimal('3.6742105263157895')),
#  (2, 173, Decimal('3.6566666666666667')),
#  (1, 239, Decimal('3.6566666666666667')),
#  (2, 246, Decimal('3.6566666666666667')),
#  (2, 38, Decimal('3.6566666666666667')),
#  (2, 503, Decimal('3.6566666666666667')),
#  (2, 241, Decimal('3.6566666666666667')),
#  (2, 464, Decimal('3.6566666666666667')),
#  (1, 374, Decimal('3.6566666666666667')),
#  (1, 435, Decimal('3.6566666666666667')),
#  (1, 156, Decimal('3.6566666666666667')),
#  (2, 414, Decimal('3.6566666666666667')),
#  (2, 483, Decimal('3.6566666666666667')),
#  (1, 141, Decimal('3.6566666666666667')),
#  (1, 263, Decimal('3.6566666666666667')),
#  (1, 17, Decimal('3.6566666666666667')),
#  (1, 202, Decimal('3.6566666666666667')),
#  (2, 71, Decimal('3.6566666666666667')),
#  (1, 254, Decimal('3.6370588235294118')),
#  (2, 521, Decimal('3.6328571428571429')),
#  (2, 177, Decimal('3.6263636363636364')),
#  (1, 479, Decimal('3.6263636363636364')),
#  (1, 220, Decimal('3.6263636363636364')),
#  (1, 290, Decimal('3.6263636363636364')),
#  (2, 357, Decimal('3.6263636363636364')),
#  (1, 599, Decimal('3.6150000000000000')),
#  (2, 366, Decimal('3.6150000000000000')),
#  (1, 96, Decimal('3.6150000000000000')),
#  (1, 199, Decimal('3.6053846153846154')),
#  (2, 133, Decimal('3.6053846153846154')),
#  (1, 268, Decimal('3.5900000000000000')),
#  (2, 1, Decimal('3.5900000000000000')),
#  (1, 534, Decimal('3.5900000000000000')),
#  (1, 353, Decimal('3.5900000000000000')),
#  (1, 6, Decimal('3.5900000000000000')),
#  (1, 474, Decimal('3.5900000000000000')),
#  (1, 549, Decimal('3.5900000000000000')),
#  (1, 450, Decimal('3.5900000000000000')),
#  (2, 302, Decimal('3.5900000000000000')),
#  (1, 392, Decimal('3.5900000000000000')),
#  (1, 68, Decimal('3.5900000000000000')),
#  (2, 69, Decimal('3.5900000000000000')),
#  (1, 351, Decimal('3.5733333333333333')),
#  (2, 406, Decimal('3.5689473684210526')),
#  (2, 219, Decimal('3.5614285714285714')),
#  (2, 292, Decimal('3.5614285714285714')),
#  (1, 587, Decimal('3.5614285714285714')),
#  (1, 588, Decimal('3.5614285714285714')),
#  (1, 597, Decimal('3.5614285714285714')),
#  (2, 30, Decimal('3.5525000000000000')),
#  (1, 538, Decimal('3.5525000000000000')),
#  (1, 386, Decimal('3.5525000000000000')),
#  (1, 205, Decimal('3.5455555555555556')),
#  (2, 456, Decimal('3.5455555555555556')),
#  (2, 330, Decimal('3.5455555555555556')),
#  (2, 561, Decimal('3.5455555555555556')),
#  (2, 131, Decimal('3.5455555555555556')),
#  (1, 214, Decimal('3.5455555555555556')),
#  (1, 158, Decimal('3.5455555555555556')),
#  (1, 165, Decimal('3.5455555555555556')),
#  (1, 162, Decimal('3.5455555555555556')),
#  (2, 355, Decimal('3.5455555555555556')),
#  (2, 340, Decimal('3.5354545454545455')),
#  (2, 233, Decimal('3.5354545454545455')),
#  (1, 237, Decimal('3.5354545454545455')),
#  (2, 254, Decimal('3.5284615384615385')),
#  (2, 260, Decimal('3.5284615384615385')),
#  (2, 361, Decimal('3.5233333333333333')),
#  (1, 442, Decimal('3.5233333333333333')),
#  (1, 372, Decimal('3.5163157894736842')),
#  (1, 163, Decimal('3.4908333333333333')),
#  (2, 67, Decimal('3.4900000000000000')),
#  (1, 503, Decimal('3.4900000000000000')),
#  (2, 162, Decimal('3.4900000000000000')),
#  ...]

# %%
# найдем среднюю продолжительность фильма в разрезе рейтингов в 2006 году
con.execute("""
SELECT rating, ROUND(AVG(length), 2) FROM film
WHERE release_year = 2006
GROUP BY rating
ORDER BY AVG(length);
""").fetchall()
# Out:
# [('G', Decimal('111.05')),
#  ('PG', Decimal('112.01')),
#  ('NC-17', Decimal('113.23')),
#  ('R', Decimal('118.66')),
#  ('PG-13', Decimal('120.44'))]

# %% [markdown]
# Оператор HAVING

# %%
# отберем только фамилий актеров, которые не повторяются
con.execute("""
SELECT last_name, COUNT(*) FROM actor
GROUP BY last_name
HAVING COUNT(*) = 1;
""").fetchall()
# Out:
# [('Grant', 1),
#  ('Gibson', 1),
#  ('Ryder', 1),
#  ('Reynolds', 1),
#  ('Stallone', 1),
#  ('Malden', 1),
#  ('Chaplin', 1),
#  ('Jovovich', 1),
#  ('Cruise', 1),
#  ('Suvari', 1),
#  ('Birch', 1),
#  ('Posey', 1),
#  ('Witherspoon', 1),
#  ('Wayne', 1),
#  ('Bacall', 1),
#  ('Hawke', 1),
#  ('Hurt', 1),
#  ('Dern', 1),
#  ('Barrymore', 1),
#  ('Nicholson', 1),
#  ('Close', 1),
#  ('Pitt', 1),
#  ('Heston', 1),
#  ('Goldberg', 1),
#  ('Day-Lewis', 1),
#  ('Bergman', 1),
#  ('Voight', 1),
#  ('Carrey', 1),
#  ('Hope', 1),
#  ('Walken', 1),
#  ('Lollobrigida', 1),
#  ('Dreyfuss', 1),
#  ('Costner', 1),
#  ('Marx', 1),
#  ('Pfeiffer', 1),
#  ('Bloom', 1),
#  ('Damon', 1),
#  ('Hunt', 1),
#  ('Sinatra', 1),
#  ('Bullock', 1),
#  ('Phoenix', 1),
#  ('Leigh', 1),
#  ('Wray', 1),
#  ('Basinger', 1),
#  ('Tomei', 1),
#  ('Hudson', 1),
#  ('Jolie', 1),
#  ('Sobieski', 1),
#  ('Dunst', 1),
#  ('Bergen', 1),
#  ('Bale', 1),
#  ('Gable', 1),
#  ('Presley', 1),
#  ('Miranda', 1),
#  ('Swank', 1),
#  ('Cruz', 1),
#  ('Pinkett', 1),
#  ('Mansfield', 1),
#  ('Astaire', 1),
#  ('Bridges', 1),
#  ('Pesci', 1),
#  ('Mcdormand', 1),
#  ('Crowe', 1),
#  ('Ball', 1),
#  ('Wilson', 1),
#  ('Tautou', 1)]

# %%
# отберем и посчитаем только фамилии актеров, которые повторяются
con.execute("""
SELECT last_name, COUNT(*) FROM actor
GROUP BY last_name
HAVING COUNT(*) > 1
ORDER BY COUNT(*) DESC;
""").fetchall()
# Out:
# [('Kilmer', 5),
#  ('Temple', 4),
#  ('Nolte', 4),
#  ('Allen', 3),
#  ('Torn', 3),
#  ('Harris', 3),
#  ('Guiness', 3),
#  ('Johansson', 3),
#  ('Degeneres', 3),
#  ('Garland', 3),
#  ('Hoffman', 3),
#  ('Akroyd', 3),
#  ('Zellweger', 3),
#  ('Williams', 3),
#  ('Willis', 3),
#  ('Hopkins', 3),
#  ('Keitel', 3),
#  ('Davis', 3),
#  ('Peck', 3),
#  ('Berry', 3),
#  ('Silverstone', 2),
#  ('Paltrow', 2),
#  ('West', 2),
#  ('Mckellen', 2),
#  ('Bailey', 2),
#  ('Hopper', 2),
#  ('Jackman', 2),
#  ('Cage', 2),
#  ('Gooding', 2),
#  ('Winslet', 2),
#  ('Mcqueen', 2),
#  ('Tracy', 2),
#  ('Penn', 2),
#  ('Dench', 2),
#  ('Bolger', 2),
#  ('Fawcett', 2),
#  ('Mcconaughey', 2),
#  ('Crawford', 2),
#  ('Monroe', 2),
#  ('Cronyn', 2),
#  ('Wood', 2),
#  ('Tandy', 2),
#  ('Dean', 2),
#  ('Chase', 2),
#  ('Olivier', 2),
#  ('Bening', 2),
#  ('Neeson', 2),
#  ('Brody', 2),
#  ('Depp', 2),
#  ('Hackman', 2),
#  ('Dee', 2),
#  ('Dukakis', 2),
#  ('Wahlberg', 2),
#  ('Mostel', 2),
#  ('Streep', 2)]

# %%
# найдем фильмы, у которых есть SUPER в названии и они сдавались в прокат суммарно более, чем на 5 дней
con.execute("""
SELECT title, SUM(rental_duration) FROM film
WHERE title LIKE '%%Super%%'
GROUP BY title
HAVING SUM(rental_duration) > 5;
""").fetchall()
# Out:
# [('Casablanca Super', 6), ('Shootist Superfly', 6)]

# %% [markdown]
# ALIAS

# %%
# Предыдущий запрос с псевдонимами
con.execute("""
SELECT title t, SUM(rental_duration) sum_t FROM film f
WHERE title LIKE '%%Super%%'
GROUP BY t
HAVING SUM(rental_duration) > 5;
""").fetchall()
# Out:
# [('Casablanca Super', 6), ('Shootist Superfly', 6)]

# %% [markdown]
# Объединение таблиц

# %%
# выведем имена, фамилии и адреса всех сотрудников
con.execute("""
SELECT first_name, last_name, address FROM staff s
LEFT JOIN address a ON s.address_id = a.address_id;
""").fetchall()
# Out:
# [('Mike', 'Hillyer', '23 Workhaven Lane'),
#  ('Jon', 'Stephens', '1411 Lillydale Drive')]

# %%
# определим количество продаж каждого продавца
con.execute("""
SELECT s.last_name, COUNT(amount) FROM payment p
LEFT JOIN staff s ON p.staff_id = s.staff_id
GROUP BY s.last_name;
""").fetchall()
# Out:
# [('Hillyer', 7292), ('Stephens', 7304)]

# %%
# посчитаем, сколько актеров играло в каждом фильме
con.execute("""
SELECT title, COUNT(actor_id) actor_q FROM film f
JOIN film_actor a ON f.film_id = a.film_id
GROUP BY title;
""").fetchall()
# Out:
# [('Graceland Dynamite', 6),
#  ('Opus Ice', 4),
#  ('Braveheart Human', 4),
#  ('Wonderful Drop', 4),
#  ('Rush Goodfellas', 5),
#  ('Purple Movie', 8),
#  ('Minority Kiss', 1),
#  ('Luke Mummy', 9),
#  ('Fantasy Troopers', 9),
#  ('Grinch Massage', 6),
#  ('Gaslight Crusade', 5),
#  ('Microcosmos Paradise', 6),
#  ('Saturn Name', 2),
#  ('Memento Zoolander', 6),
#  ('Sunset Racer', 3),
#  ('Zoolander Fiction', 5),
#  ('Carol Texas', 7),
#  ('Stepmom Dream', 4),
#  ('Minds Truman', 6),
#  ('Gump Date', 6),
#  ('Arabia Dogma', 12),
#  ('Baked Cleopatra', 1),
#  ('Closer Bang', 6),
#  ('Enough Raging', 9),
#  ('Grosse Wonderful', 4),
#  ('Innocent Usual', 3),
#  ('Sleepless Monsoon', 4),
#  ('Suit Walls', 5),
#  ('Wizard Coldblooded', 9),
#  ('Lonely Elephant', 12),
#  ('Victory Academy', 5),
#  ('Bedazzled Married', 7),
#  ('Tadpole Park', 8),
#  ('Maker Gables', 11),
#  ('Private Drop', 5),
#  ('Worker Tarzan', 9),
#  ('Gosford Donnie', 3),
#  ('Annie Identity', 3),
#  ('Drop Waterfront', 8),
#  ('Lesson Cleopatra', 12),
#  ('Wanda Chamber', 7),
#  ('Dwarfs Alter', 1),
#  ('Garden Island', 3),
#  ('Graduate Lord', 2),
#  ('Patriot Roman', 4),
#  ('Novocaine Flight', 6),
#  ('Necklace Outbreak', 8),
#  ('Menagerie Rushmore', 2),
#  ('Sleeping Suspects', 4),
#  ('Uncut Suicides', 7),
#  ('Midnight Westward', 9),
#  ('Rock Instinct', 8),
#  ('Jersey Sassy', 9),
#  ('Magnificent Chitty', 7),
#  ('Clones Pinocchio', 5),
#  ('Insects Stone', 4),
#  ('Giant Troopers', 1),
#  ('Loser Hustler', 5),
#  ('Heavyweights Beast', 5),
#  ('Boondock Ballroom', 13),
#  ('Entrapment Satisfaction', 4),
#  ('Firehouse Vietnam', 5),
#  ('Core Suit', 4),
#  ('Butch Panther', 3),
#  ('Cyclone Family', 3),
#  ('Cabin Flash', 4),
#  ('Jaws Harry', 5),
#  ('Fellowship Autumn', 7),
#  ('Bowfinger Gables', 5),
#  ('Birdcage Casper', 4),
#  ('Forever Candidate', 1),
#  ('Dangerous Uptown', 8),
#  ('Guys Falcon', 5),
#  ('Warlock Werewolf', 6),
#  ('None Spiking', 6),
#  ('Bringing Hysterical', 2),
#  ('Haunting Pianist', 5),
#  ('Agent Truman', 7),
#  ('Motions Details', 8),
#  ('Tenenbaums Command', 5),
#  ('Secrets Paradise', 6),
#  ('Tarzan Videotape', 3),
#  ('Double Wrath', 8),
#  ('Greatest North', 6),
#  ('Birch Antitrust', 6),
#  ('Sense Greek', 7),
#  ('Walls Artist', 5),
#  ('Invasion Cyclone', 7),
#  ('Secretary Rouge', 6),
#  ('Congeniality Quest', 3),
#  ('Daughter Madigan', 4),
#  ('Crossroads Casualties', 8),
#  ('Canyon Stock', 6),
#  ('Reef Salute', 4),
#  ('French Holiday', 7),
#  ('Rugrats Shakespeare', 6),
#  ('Highball Potter', 5),
#  ('Papi Necklace', 3),
#  ('Translation Summer', 3),
#  ('Peak Forever', 5),
#  ('Tycoon Gathering', 6),
#  ('Loverboy Attacks', 9),
#  ('Earring Instinct', 5),
#  ('Ship Wonderland', 8),
#  ('Rouge Squad', 4),
#  ('Clue Grail', 6),
#  ('Wonderland Christmas', 5),
#  ('Finding Anaconda', 5),
#  ('Thin Sagebrush', 2),
#  ('Nash Chocolat', 7),
#  ('Wrath Mile', 4),
#  ('Harold French', 7),
#  ('Forrest Sons', 5),
#  ('Pure Runner', 2),
#  ('Witches Panic', 4),
#  ('Turn Star', 3),
#  ('Anthem Luke', 2),
#  ('Duffel Apocalypse', 3),
#  ('Shrek License', 3),
#  ('Heaven Freedom', 10),
#  ('Impossible Prejudice', 3),
#  ('Peach Innocent', 5),
#  ('Dazed Punk', 6),
#  ('Frisco Forrest', 9),
#  ('Reds Pocus', 5),
#  ('Music Boondock', 3),
#  ('Chisum Behavior', 4),
#  ('Volcano Texas', 5),
#  ('Daisy Menagerie', 7),
#  ('Lost Bird', 3),
#  ('Caribbean Liberty', 8),
#  ('Conversation Downhill', 3),
#  ('Lambs Cincinatti', 15),
#  ('Escape Metropolis', 4),
#  ('Dumbo Lust', 9),
#  ('Pizza Jumanji', 5),
#  ('Hills Neighbors', 6),
#  ('Truman Crazy', 6),
#  ('Chance Resurrection', 6),
#  ('Candidate Perdition', 4),
#  ('Spiking Element', 6),
#  ('Fight Jawbreaker', 3),
#  ('Apache Divine', 4),
#  ('Shining Roses', 5),
#  ('Ishtar Rocketeer', 4),
#  ('Flying Hook', 8),
#  ('Desperate Trainspotting', 4),
#  ('Greedy Roots', 8),
#  ('Forrester Comancheros', 3),
#  ('Dirty Ace', 5),
#  ('Trading Pinocchio', 3),
#  ('Graffiti Love', 6),
#  ('Paths Control', 5),
#  ('Amelie Hellfighters', 6),
#  ('Pickup Driving', 5),
#  ('Panic Club', 3),
#  ('Crazy Home', 13),
#  ('Forward Temple', 3),
#  ('Vertigo Northwest', 4),
#  ('Jericho Mulan', 4),
#  ('Gunfighter Mussolini', 4),
#  ('Bilko Anonymous', 3),
#  ('Blade Polish', 5),
#  ('Spice Sorority', 11),
#  ('Massage Image', 9),
#  ('Home Pity', 6),
#  ('Boulevard Mob', 8),
#  ('Dalmations Sweden', 6),
#  ('Hunter Alter', 4),
#  ('Zorro Ark', 3),
#  ('Silence Kane', 4),
#  ('Taxi Kick', 6),
#  ('Resurrection Silverado', 5),
#  ('Suspects Quills', 8),
#  ('Dracula Crystal', 13),
#  ('Harper Dying', 4),
#  ('Simon North', 3),
#  ('Vacation Boondock', 6),
#  ('Chitty Lock', 13),
#  ('Ballroom Mockingbird', 7),
#  ('Legally Secretary', 6),
#  ('Gladiator Westward', 6),
#  ('Barefoot Manchurian', 8),
#  ('Cruelty Unforgiven', 2),
#  ('Smoking Barbarella', 6),
#  ('Soldiers Evolution', 9),
#  ('Robbers Joon', 5),
#  ('Telemark Heartbreakers', 11),
#  ('Westward Seabiscuit', 6),
#  ('Notorious Reunion', 2),
#  ('Million Ace', 5),
#  ('Ali Forever', 5),
#  ('Coneheads Smoochy', 9),
#  ('Suicides Silence', 3),
#  ('Bird Independence', 2),
#  ('Intrigue Worst', 7),
#  ('Mask Peach', 11),
#  ('Scissorhands Slums', 5),
#  ('Boiled Dares', 8),
#  ('Majestic Floats', 5),
#  ('Past Suicides', 6),
#  ('Masked Bubble', 3),
#  ('Bull Shawshank', 8),
#  ('Gunfight Moon', 4),
#  ('Sagebrush Clueless', 7),
#  ('Reap Unfaithful', 4),
#  ('Lock Rear', 2),
#  ('Beethoven Exorcist', 6),
#  ('Vietnam Smoochy', 2),
#  ('Breaking Home', 6),
#  ('Runaway Tenenbaums', 3),
#  ('Head Stranger', 2),
#  ('Quest Mussolini', 5),
#  ('Ace Goldfinger', 4),
#  ('Dancing Fever', 6),
#  ('Image Princess', 11),
#  ('Fool Mockingbird', 2),
#  ('Panther Reds', 5),
#  ('Holocaust Highball', 5),
#  ('Bright Encounters', 4),
#  ('Adaptation Holes', 5),
#  ('Deceiver Betrayed', 4),
#  ('Antitrust Tomatoes', 7),
#  ('Fatal Haunted', 6),
#  ('Sons Interview', 6),
#  ('Yentl Idaho', 1),
#  ('Modern Dorado', 5),
#  ('Rage Games', 7),
#  ('Monsoon Cause', 5),
#  ('Uprising Uptown', 5),
#  ('Jason Trap', 5),
#  ('Sweet Brotherhood', 6),
#  ('Crusade Honey', 9),
#  ('Arachnophobia Rollercoaster', 8),
#  ('Stallion Sundance', 7),
#  ('Crossing Divorce', 2),
#  ('Creatures Shakespeare', 3),
#  ('Easy Gladiator', 3),
#  ('Snatchers Montezuma', 9),
#  ('Shock Cabin', 1),
#  ('Island Exorcist', 3),
#  ('Seattle Expecations', 6),
#  ('Liberty Magnificent', 7),
#  ('Gun Bonnie', 5),
#  ('Alabama Devil', 9),
#  ('Train Bunch', 4),
#  ('Identity Lover', 4),
#  ('Clyde Theory', 4),
#  ('Troopers Metal', 5),
#  ('Primary Glass', 7),
#  ('Frankenstein Stranger', 2),
#  ('Excitement Eve', 8),
#  ('Affair Prejudice', 5),
#  ('Impact Aladdin', 3),
#  ('Fury Murder', 4),
#  ('Deep Crusade', 7),
#  ('Sierra Divide', 5),
#  ('Dinosaur Secretary', 6),
#  ('Kill Brotherhood', 5),
#  ('Muppet Mile', 8),
#  ('Mosquito Armageddon', 4),
#  ('Freedom Cleopatra', 5),
#  ('Jungle Closer', 6),
#  ('Indian Love', 10),
#  ('Glass Dying', 4),
#  ('Born Spinal', 9),
#  ('Life Twisted', 8),
#  ('Massacre Usual', 3),
#  ('Kissing Dolls', 3),
#  ('Greek Everyone', 4),
#  ('Meet Chocolate', 6),
#  ('Dorado Notting', 4),
#  ('Titans Jerk', 7),
#  ('Hanging Deep', 7),
#  ('Streetcar Intentions', 7),
#  ('Hardly Robbers', 3),
#  ('War Notting', 9),
#  ('Diary Panic', 4),
#  ('Instinct Airport', 11),
#  ('Bikini Borrowers', 2),
#  ('Rebel Airport', 6),
#  ('Flamingos Connecticut', 9),
#  ('Cincinatti Whisperer', 4),
#  ('Trainspotting Strangers', 4),
#  ('Pelican Comforts', 5),
#  ('Madre Gables', 4),
#  ('Lord Arizona', 6),
#  ('Feathers Metal', 9),
#  ('Hook Chariots', 4),
#  ('Groove Fiction', 7),
#  ('Window Side', 4),
#  ('Silverado Goldfinger', 5),
#  ('Mannequin Worst', 5),
#  ('Willow Tracy', 2),
#  ('Hocus Frida', 3),
#  ('Natural Stock', 4),
#  ('Karate Moon', 8),
#  ('Roses Treasure', 5),
#  ('Racer Egg', 6),
#  ('Jawbreaker Brooklyn', 5),
#  ('Alice Fantasia', 4),
#  ('Mixed Doors', 6),
#  ('Potter Connecticut', 7),
#  ('Order Betrayed', 7),
#  ('Mighty Luck', 8),
#  ('Sabrina Midnight', 4),
#  ('Roxanne Rebel', 5),
#  ('Fidelity Devil', 4),
#  ('Madness Attacks', 7),
#  ('Mussolini Spoilers', 7),
#  ('Star Operation', 5),
#  ('Vanilla Day', 2),
#  ('Bunch Minds', 8),
#  ('Sweethearts Suspects', 5),
#  ('Lola Agent', 6),
#  ('Won Dares', 5),
#  ('Reunion Witches', 7),
#  ('Unfaithful Kill', 8),
#  ('Encino Elf', 6),
#  ('Hustler Party', 4),
#  ('Rollercoaster Bringing', 3),
#  ('Spirit Flintstones', 11),
#  ('Details Packer', 2),
#  ('Pianist Outfield', 5),
#  ('Luck Opus', 6),
#  ('Butterfly Chocolat', 7),
#  ('Mallrats United', 5),
#  ('Queen Luke', 6),
#  ('Desire Alien', 7),
#  ('Glory Tracy', 6),
#  ('Bound Cheaper', 2),
#  ('Academy Dinosaur', 10),
#  ('Igby Maker', 5),
#  ('Gentlemen Stage', 8),
#  ('Pollock Deliverance', 6),
#  ('Sleuth Orient', 7),
#  ('Freddy Storm', 3),
#  ('Odds Boogie', 5),
#  ('Prejudice Oleander', 10),
#  ('Cowboy Doom', 5),
#  ('Valentine Vanishing', 2),
#  ('Show Lord', 2),
#  ('Confidential Interview', 2),
#  ('Armageddon Lost', 7),
#  ('Edge Kissing', 3),
#  ('Grail Frankenstein', 5),
#  ('Half Outfield', 6),
#  ('Love Suicides', 4),
#  ('Seven Swarm', 7),
#  ('Oscar Gold', 6),
#  ('Lies Treatment', 7),
#  ('Chocolat Harry', 5),
#  ('Wind Phantom', 3),
#  ('Casablanca Super', 4),
#  ('Random Go', 13),
#  ('Newsies Story', 8),
#  ('Knock Warlock', 6),
#  ('Leathernecks Dwarfs', 7),
#  ('Joon Northwest', 2),
#  ('Pajama Jawbreaker', 5),
#  ('Stage World', 2),
#  ('American Circus', 5),
#  ('Rear Trading', 8),
#  ('Siege Madre', 7),
#  ('Angels Life', 9),
#  ('Crooked Frogmen', 6),
#  ('Jingle Sagebrush', 2),
#  ('Tramp Others', 6),
#  ('Artist Coldblooded', 7),
#  ('Beverly Outlaw', 4),
#  ('Doom Dancing', 8),
#  ('Mine Titans', 2),
#  ('Hunting Musketeers', 5),
#  ('Rings Heartbreakers', 11),
#  ('Lights Deer', 2),
#  ('Mars Roman', 7),
#  ('Champion Flatliners', 4),
#  ('Temple Attraction', 5),
#  ('Roman Punk', 2),
#  ('Dragon Squad', 8),
#  ('Moulin Wake', 3),
#  ('Fiction Christmas', 8),
#  ('Princess Giant', 5),
#  ('Empire Malkovich', 9),
#  ('Fish Opus', 2),
#  ('Tequila Past', 3),
#  ('Rocketeer Mother', 7),
#  ('Theory Mermaid', 6),
#  ('Divine Resurrection', 5),
#  ('Manchurian Curtain', 2),
#  ('Casper Dragonfly', 5),
#  ('Mulan Moon', 5),
#  ('Newton Labyrinth', 4),
#  ('Bubble Grosse', 3),
#  ('Lebowski Soldiers', 3),
#  ('Berets Agent', 10),
#  ('Searchers Wait', 4),
#  ('South Wait', 2),
#  ('Uptown Young', 7),
#  ('Center Dinosaur', 4),
#  ('Spartacus Cheaper', 3),
#  ('Wedding Apollo', 10),
#  ('Dawn Pond', 6),
#  ('Perfect Groove', 6),
#  ('Ties Hunger', 6),
#  ('Satisfaction Confidential', 5),
#  ('Speed Suit', 6),
#  ('Halloween Nuts', 7),
#  ('Vision Torque', 5),
#  ('Blackout Private', 5),
#  ('Iron Moon', 8),
#  ('Bonnie Holocaust', 9),
#  ('Coma Head', 3),
#  ('Disciple Mother', 7),
#  ('Vanishing Rocky', 5),
#  ('Floats Garden', 5),
#  ('Paris Weekend', 6),
#  ('Bill Others', 6),
#  ('Expendable Stallion', 4),
#  ('Mob Duffel', 6),
#  ('Patton Interview', 9),
#  ('Club Graffiti', 4),
#  ('Alien Center', 6),
#  ('Jade Bunch', 8),
#  ('Network Peak', 3),
#  ('Name Detective', 3),
#  ('Outfield Massacre', 4),
#  ('Watership Frontier', 6),
#  ('Trojan Tomorrow', 8),
#  ('Apocalypse Flamingos', 5),
#  ('Cat Coneheads', 4),
#  ('Varsity Trip', 3),
#  ('Strangelove Desire', 9),
#  ('Egypt Tenenbaums', 5),
#  ('Pirates Roxanne', 1),
#  ('Divorce Shining', 6),
#  ('Vampire Whale', 5),
#  ('Oz Liaisons', 11),
#  ('Ghostbusters Elf', 1),
#  ('Traffic Hobbit', 4),
#  ('Whale Bikini', 5),
#  ('Nuts Ties', 2),
#  ('Moonwalker Fool', 7),
#  ('Cheaper Clyde', 2),
#  ('Watch Tracy', 5),
#  ('Lust Lock', 7),
#  ('Citizen Shrek', 8),
#  ('Command Darling', 8),
#  ('Heartbreakers Bright', 5),
#  ('Patient Sister', 4),
#  ('Outbreak Divine', 5),
#  ('Bed Highball', 5),
#  ('Requiem Tycoon', 8),
#  ('National Story', 7),
#  ('Jeepers Wedding', 6),
#  ('Frida Slipper', 5),
#  ('Mourning Purple', 7),
#  ('Language Cowboy', 6),
#  ('Doors President', 9),
#  ('Barbarella Streetcar', 5),
#  ('Hoosiers Birdcage', 10),
#  ('Blindness Gun', 3),
#  ('Maltese Hope', 1),
#  ('Chamber Italian', 7),
#  ('Moon Bunch', 1),
#  ('Tomatoes Hellfighters', 9),
#  ('Army Flintstones', 7),
#  ('Wonka Sea', 2),
#  ('Hedwig Alter', 4),
#  ('Honey Ties', 5),
#  ('Hurricane Affair', 3),
#  ('Nightmare Chill', 2),
#  ('Matrix Snowman', 3),
#  ('Shootist Superfly', 3),
#  ('Hanky October', 3),
#  ('Orient Closer', 4),
#  ('Lawrence Love', 2),
#  ('Usual Untouchables', 5),
#  ('Squad Fish', 5),
#  ('Shakespeare Saddle', 6),
#  ('Shepherd Midsummer', 5),
#  ('Wisdom Worker', 7),
#  ('African Egg', 5),
#  ('Family Sweet', 9),
#  ('Wait Cider', 9),
#  ('October Submarine', 5),
#  ('World Leathernecks', 8),
#  ('Encounters Curtain', 4),
#  ('California Birds', 2),
#  ('Apollo Teen', 8),
#  ('Brooklyn Desert', 5),
#  ('Dream Pickup', 4),
#  ('Phantom Glory', 2),
#  ('Arizona Bang', 4),
#  ('Midsummer Groundhog', 2),
#  ('Alaska Phantom', 7),
#  ('Stampede Disturbing', 6),
#  ('Attraction Newton', 4),
#  ('Earth Vision', 3),
#  ('Telegraph Voyage', 7),
#  ('Clueless Bucket', 8),
#  ('King Evolution', 6),
#  ('Hall Cassidy', 5),
#  ('Slums Duck', 3),
#  ('Desert Poseidon', 5),
#  ('Bride Intrigue', 1),
#  ('Wardrobe Phantom', 8),
#  ('Gangs Pride', 4),
#  ('Games Bowfinger', 8),
#  ('Sensibility Rear', 6),
#  ('Pluto Oleander', 7),
#  ('Homicide Peach', 8),
#  ('Kick Savannah', 6),
#  ('Darko Dorado', 4),
#  ('Ladybugs Armageddon', 4),
#  ('Lion Uncut', 3),
#  ('Creepers Kane', 6),
#  ('Superfly Trip', 7),
#  ('Song Hedwig', 5),
#  ('President Bang', 5),
#  ('Loathing Legally', 5),
#  ('Northwest Polish', 8),
#  ('Gilmore Boiled', 6),
#  ('Tracy Cider', 3),
#  ('Doctor Grail', 6),
#  ('Wars Pluto', 4),
#  ('Jumanji Blade', 6),
#  ('Noon Papi', 6),
#  ('Bang Kwai', 7),
#  ('Disturbing Scarface', 4),
#  ('Robbery Bright', 2),
#  ('Vanished Garden', 2),
#  ('Dolls Rage', 1),
#  ('Borrowers Bedazzled', 7),
#  ('Crystal Breaking', 5),
#  ('Tootsie Pilot', 5),
#  ('Spy Mile', 8),
#  ('Operation Operation', 3),
#  ('Destiny Saturday', 7),
#  ('Homeward Cider', 7),
#  ('Galaxy Sweethearts', 3),
#  ('Sorority Queen', 4),
#  ('Groundhog Uncut', 7),
#  ('Santa Paris', 6),
#  ('Pittsburgh Hunchback', 5),
#  ('Hyde Doctor', 6),
#  ('Open African', 9),
#  ('Jacket Frisco', 10),
#  ('Untouchables Sunrise', 5),
#  ('Sugar Wonka', 5),
#  ('Videotape Arsenic', 5),
#  ('English Bulworth', 5),
#  ('Chill Luck', 5),
#  ('Packer Madigan', 1),
#  ('Metropolis Coma', 6),
#  ('Chainsaw Uptown', 2),
#  ('Autumn Crow', 3),
#  ('Roots Remember', 10),
#  ('Divide Monster', 6),
#  ('Frost Head', 7),
#  ('Saints Bride', 10),
#  ('Lucky Flying', 10),
#  ('Caddyshack Jedi', 7),
#  ('Airport Pollock', 4),
#  ('Raiders Antitrust', 6),
#  ('Express Lonely', 8),
#  ('Date Speed', 4),
#  ('Happiness United', 5),
#  ('Thief Pelican', 7),
#  ('Moonshine Cabin', 5),
#  ('Submarine Bed', 11),
#  ('Clerks Angels', 4),
#  ('Unforgiven Zoolander', 7),
#  ('Amadeus Holy', 6),
#  ('Musketeers Wait', 1),
#  ('Malkovich Pet', 7),
#  ('Heavenly Gun', 6),
#  ('Chaplin License', 6),
#  ('Anything Savannah', 3),
#  ('Elizabeth Shane', 3),
#  ('Outlaw Hanky', 7),
#  ('Blues Instinct', 4),
#  ('Maiden Home', 8),
#  ('Torque Bound', 5),
#  ('Airplane Sierra', 5),
#  ('Weekend Personal', 10),
#  ('Werewolf Lola', 7),
#  ('Bucket Brotherhood', 6),
#  ('Hellfighters Sierra', 12),
#  ('Bear Graceland', 3),
#  ('School Jacket', 8),
#  ('Strangers Graffiti', 5),
#  ('Zhivago Core', 6),
#  ('Inch Jet', 5),
#  ('Driver Annie', 8),
#  ('Tourist Pelican', 3),
#  ('Beneath Rush', 7),
#  ('Goodfellas Salute', 8),
#  ('Conquerer Nuts', 6),
#  ('Polish Brooklyn', 10),
#  ('Elf Murder', 5),
#  ('Japanese Run', 9),
#  ('Stagecoach Armageddon', 6),
#  ('Ark Ridgemont', 3),
#  ('Hanover Galaxy', 7),
#  ('Italian African', 2),
#  ('Rainbow Shock', 6),
#  ('Amistad Midsummer', 4),
#  ('League Hellfighters', 6),
#  ('Fever Empire', 3),
#  ('Trip Newton', 4),
#  ('Reign Gentlemen', 3),
#  ('Perdition Fargo', 5),
#  ('Flatliners Killer', 9),
#  ('Villain Desperate', 2),
#  ('Spinal Rocky', 8),
#  ('Early Home', 6),
#  ('Clockwork Paradise', 5),
#  ('Jet Neighbors', 6),
#  ('Breakfast Goldfinger', 5),
#  ('Sunrise League', 5),
#  ('Paradise Sabrina', 4),
#  ('Speakeasy Date', 3),
#  ('Wash Heavenly', 5),
#  ('Tights Dawn', 5),
#  ('Backlash Undefeated', 7),
#  ('Sea Virgin', 8),
#  ('Legend Jedi', 4),
#  ('Control Anthem', 3),
#  ('Cider Desire', 5),
#  ('Prix Undefeated', 7),
#  ('Behavior Runaway', 5),
#  ('Downhill Enough', 4),
#  ('Dances None', 5),
#  ('Fargo Gandhi', 5),
#  ('Volume House', 5),
#  ('Gandhi Kwai', 8),
#  ('Kentuckian Giant', 4),
#  ('Fiddler Lost', 11),
#  ('Rules Human', 5),
#  ('Super Wyoming', 3),
#  ('Aladdin Calendar', 8),
#  ('Exorcist Sting', 5),
#  ('Magic Mallrats', 4),
#  ('Harry Idaho', 6),
#  ('Basic Easy', 6),
#  ('Orange Grapes', 5),
#  ('Contact Anonymous', 5),
#  ('Cassidy Wyoming', 7),
#  ('Kane Exorcist', 5),
#  ('Sweden Shining', 5),
#  ('Mission Zoolander', 5),
#  ('Model Fish', 8),
#  ('Alone Trip', 8),
#  ('Youth Kick', 5),
#  ('Town Ark', 4),
#  ('Darling Breaking', 2),
#  ('Crow Grease', 10),
#  ('Sun Confessions', 5),
#  ('Day Unfaithful', 5),
#  ('Pilot Hoosiers', 7),
#  ('Psycho Shrunk', 1),
#  ('Philadelphia Wife', 2),
#  ('Wife Turn', 6),
#  ('Holes Brannigan', 11),
#  ('Valley Packer', 4),
#  ('Coldblooded Darling', 4),
#  ('Horror Reign', 5),
#  ('Color Philadelphia', 7),
#  ('Banger Pinocchio', 6),
#  ('Streak Ridgemont', 3),
#  ('Steel Santa', 3),
#  ('Teen Apollo', 5),
#  ('Bulworth Commandments', 4),
#  ('Neighbors Charade', 7),
#  ('Trap Guys', 7),
#  ('Boogie Amelie', 6),
#  ('Grit Clockwork', 3),
#  ('Haunted Antitrust', 5),
#  ('Eagles Panky', 6),
#  ('Shane Darkness', 3),
#  ('Stone Fire', 1),
#  ('Effect Gladiator', 7),
#  ('Young Language', 5),
#  ('Candles Grapes', 7),
#  ('Darn Forrester', 9),
#  ('Hotel Happiness', 4),
#  ('Chinatown Gladiator', 10),
#  ('Splendor Patton', 10),
#  ('Alamo Videotape', 4),
#  ('Hunger Roof', 1),
#  ('Independence Hotel', 9),
#  ('Arsenic Independence', 3),
#  ('Hysterical Grail', 9),
#  ('Mermaid Insects', 6),
#  ('Brannigan Sunrise', 2),
#  ('Unbreakable Karate', 8),
#  ('High Encino', 7),
#  ('Hamlet Wisdom', 5),
#  ('Lose Inch', 4),
#  ('Devil Desire', 5),
#  ('Everyone Craft', 5),
#  ('Hunchback Impossible', 2),
#  ('Virtual Spoilers', 3),
#  ('Run Pacific', 6),
#  ('Connecticut Tramp', 7),
#  ('Ice Crossing', 6),
#  ('Daddy Pittsburgh', 5),
#  ('Betrayed Rear', 4),
#  ('Factory Dragon', 6),
#  ('Analyze Hoosiers', 5),
#  ('Working Microcosmos', 5),
#  ('Flintstones Happiness', 4),
#  ('Mod Secretary', 6),
#  ('Ferris Mother', 1),
#  ('Fire Wolves', 5),
#  ('Lawless Vision', 4),
#  ('Splash Gump', 10),
#  ('Comancheros Enemy', 5),
#  ('Jumping Wrath', 8),
#  ('Shawshank Bubble', 10),
#  ('Voice Peach', 3),
#  ('Waterfront Deliverance', 6),
#  ('Personal Ladybugs', 9),
#  ('Wrong Behavior', 9),
#  ('Cause Date', 6),
#  ('Bugsy Song', 2),
#  ('Montezuma Command', 2),
#  ('Curtain Videotape', 3),
#  ('Worst Banger', 4),
#  ('Holiday Games', 6),
#  ('Fireball Philadelphia', 5),
#  ('Eve Resurrection', 6),
#  ('Gables Metropolis', 8),
#  ('Talented Homicide', 5),
#  ('Words Hunter', 6),
#  ('Records Zorro', 8),
#  ('Element Freddy', 4),
#  ('Spirited Casualties', 5),
#  ('Egg Igby', 5),
#  ('Seabiscuit Punk', 3),
#  ('Magnolia Forrester', 7),
#  ('Cupboard Sinners', 8),
#  ('Tuxedo Mile', 3),
#  ('Beach Heartbreakers', 7),
#  ('Human Graffiti', 4),
#  ('Louisiana Harry', 3),
#  ('Donnie Alley', 7),
#  ('Something Duck', 3),
#  ('Pity Bound', 5),
#  ('Evolution Alter', 6),
#  ('Hope Tootsie', 4),
#  ('Treatment Jekyll', 5),
#  ('Flash Wars', 7),
#  ('Crowds Telemark', 4),
#  ('Pocus Pulp', 5),
#  ('Voyage Legally', 5),
#  ('Trouble Date', 8),
#  ('Sky Miracle', 12),
#  ('Alley Evolution', 5),
#  ('Hollywood Anonymous', 6),
#  ('Coast Rainbow', 10),
#  ('Mummy Creatures', 13),
#  ('Room Roman', 2),
#  ('Dozen Lion', 6),
#  ('Casualties Encino', 5),
#  ('Frontier Cabin', 6),
#  ('Velvet Terminator', 9),
#  ('Money Harold', 7),
#  ('Sling Luke', 3),
#  ('Pacific Amistad', 8),
#  ('Eyes Driving', 5),
#  ('Wasteland Divine', 6),
#  ('Dares Pluto', 10),
#  ('Gleaming Jawbreaker', 8),
#  ('Fantasia Park', 3),
#  ('Saturday Lambs', 9),
#  ('Beast Hunchback', 5),
#  ('Commandments Express', 4),
#  ('Roof Champion', 5),
#  ('Kramer Chocolate', 8),
#  ('Pinocchio Simon', 11),
#  ('Catch Amistad', 5),
#  ('Wolves Desire', 6),
#  ('Wyoming Storm', 6),
#  ('Maguire Apache', 4),
#  ('Carrie Bunch', 7),
#  ('Jeopardy Encino', 5),
#  ('Labyrinth League', 6),
#  ('Juggler Hardly', 9),
#  ('Brotherhood Blanket', 5),
#  ('Poseidon Forever', 6),
#  ('Texas Watch', 6),
#  ('Women Dorado', 5),
#  ('Strictly Scarface', 4),
#  ('Charade Duffel', 3),
#  ('Summer Scarface', 8),
#  ('Lolita World', 1),
#  ('Mile Mulan', 3),
#  ('Rocky War', 3),
#  ('Cleopatra Devil', 7),
#  ('Kiss Glory', 7),
#  ('Pride Alamo', 4),
#  ('Jedi Beneath', 4),
#  ('Ridgemont Submarine', 5),
#  ('Chariots Conspiracy', 2),
#  ('Redemption Comforts', 5),
#  ('Informer Double', 3),
#  ('Scarface Bang', 7),
#  ('Titanic Boondock', 12),
#  ('Interview Liaisons', 5),
#  ('Smoochy Control', 2),
#  ('Steers Armageddon', 4),
#  ('Runner Madigan', 8),
#  ('Range Moonwalker', 4),
#  ('Remember Diary', 4),
#  ('Wild Apollo', 4),
#  ('Go Purple', 3),
#  ('Jekyll Frogmen', 3),
#  ('Opposite Necklace', 6),
#  ('Pet Haunting', 7),
#  ('Scalawag Duck', 5),
#  ('Enemy Odds', 4),
#  ('Camelot Vacation', 2),
#  ('Illusion Amelie', 7),
#  ('Chocolate Duck', 7),
#  ('Bingo Talented', 5),
#  ('Twisted Pirates', 3),
#  ('Gold River', 2),
#  ('Miracle Virtual', 1),
#  ('Dude Blindness', 7),
#  ('Undefeated Dalmations', 3),
#  ('Kwai Homeward', 5),
#  ('Insider Arizona', 9),
#  ('Campus Remember', 3),
#  ('Jerk Paycheck', 8),
#  ('Baby Hall', 8),
#  ('Killer Innocent', 5),
#  ('Sassy Packer', 3),
#  ('Sleepy Japanese', 6),
#  ('Blanket Beverly', 4),
#  ('Treasure Command', 7),
#  ('Platoon Instinct', 5),
#  ('Chicken Hellfighters', 2),
#  ('Pulp Beverly', 7),
#  ('Quills Bull', 4),
#  ('Shrunk Divine', 4),
#  ('Dragonfly Strangers', 3),
#  ('Lady Stage', 8),
#  ('Virgin Daisy', 8),
#  ('Argonauts Town', 5),
#  ('Gorgeous Bingo', 7),
#  ('Storm Happiness', 8),
#  ('Stock Glass', 7),
#  ('Sinners Atlantis', 4),
#  ('Monterey Labyrinth', 6),
#  ('Hours Rage', 6),
#  ('Driving Polish', 7),
#  ('Grease Youth', 3),
#  ('West Lion', 9),
#  ('Ghost Groundhog', 5),
#  ('Snatch Slipper', 3),
#  ('Horn Working', 8),
#  ('Lovely Jingle', 6),
#  ('Hawk Chill', 7),
#  ('Terminator Club', 2),
#  ('Rushmore Mermaid', 7),
#  ('Deer Virginian', 3),
#  ('Alter Victory', 4),
#  ('Darkness War', 2),
#  ('Falcon Volume', 4),
#  ('Mother Oleander', 5),
#  ('Shanghai Tycoon', 8),
#  ('Attacks Hate', 4),
#  ('Paycheck Wait', 3),
#  ('Rider Caddyshack', 9),
#  ('Drifter Commandments', 7),
#  ('Swarm Gold', 6),
#  ('Married Go', 3),
#  ('Badman Dawn', 8),
#  ('License Weekend', 8),
#  ('United Pilot', 6),
#  ('Scorpion Apollo', 8),
#  ('Atlantis Cause', 9),
#  ('Timberland Sky', 4),
#  ('Feud Frogmen', 4),
#  ('Reservoir Adaptation', 8),
#  ('Celebrity Horn', 4),
#  ('Mystic Truman', 4),
#  ('Straight Hours', 3),
#  ('Holy Tadpole', 3),
#  ('Goldmine Tycoon', 7),
#  ('Punk Divorce', 7),
#  ('Oklahoma Jumanji', 9),
#  ('Extraordinary Conquerer', 7),
#  ('Godfather Diary', 6),
#  ('Liaisons Sweet', 6),
#  ('Chasing Fight', 5),
#  ('Others Soup', 4),
#  ('Wagon Jaws', 6),
#  ('Hobbit Alien', 8),
#  ('Gone Trouble', 5),
#  ('Anonymous Human', 9),
#  ('Metal Armageddon', 8),
#  ('Grapes Fury', 5),
#  ('Goldfinger Sensibility', 4),
#  ('Whisperer Giant', 3),
#  ('Sting Personal', 7),
#  ('Deliverance Mulholland', 3),
#  ('Craft Outfield', 6),
#  ('Dogma Family', 7),
#  ('Cranes Reservoir', 6),
#  ('Salute Apollo', 4),
#  ('Frogmen Breaking', 6),
#  ('Spoilers Hellfighters', 7),
#  ('Towers Hurricane', 4),
#  ('Potluck Mixed', 6),
#  ('Intentions Empire', 2),
#  ('Gilbert Pelican', 4),
#  ('Blood Argonauts', 4),
#  ('Durham Panky', 9),
#  ('Comforts Rush', 5),
#  ('Movie Shakespeare', 8),
#  ('House Dynamite', 9),
#  ('Sister Freddy', 3),
#  ('Madigan Dorado', 6),
#  ('Saddle Antitrust', 3),
#  ('Panky Submarine', 8),
#  ('Caper Motions', 7),
#  ('Side Ark', 6),
#  ('Wake Jaws', 5),
#  ('Raging Airplane', 3),
#  ('Stranger Strangers', 9),
#  ('Confessions Maguire', 4),
#  ('Monster Spartacus', 7),
#  ('Connection Microcosmos', 7),
#  ('Handicap Boondock', 7),
#  ('Duck Racer', 2),
#  ('Madison Trap', 5),
#  ('State Wasteland', 7),
#  ('Confused Candles', 6),
#  ('Muscle Bright', 5),
#  ('Hollow Jeopardy', 2),
#  ('Clash Freddy', 7),
#  ('Elephant Trojan', 5),
#  ('Sundance Invasion', 7),
#  ('Idols Snatchers', 8),
#  ('Snowman Rollercoaster', 3),
#  ('Conspiracy Spirit', 4),
#  ('Freaky Pocus', 5),
#  ('Soup Wisdom', 2),
#  ('Hate Handicap', 3),
#  ('Notting Speakeasy', 2),
#  ('Story Side', 5),
#  ('Ending Crowds', 5),
#  ('Mulholland Beast', 6),
#  ('Calendar Gunfight', 8),
#  ('Birds Perdition', 4),
#  ('Destination Jerk', 3),
#  ('Smile Earring', 8),
#  ('Maude Mod', 6),
#  ('Party Knock', 2),
#  ('Dying Maker', 2),
#  ('Fugitive Maguire', 11),
#  ('Tomorrow Hustler', 6),
#  ('Doubtfire Labyrinth', 5),
#  ('Park Citizen', 6),
#  ('Full Flatliners', 6),
#  ('Savannah Town', 6),
#  ('Dynamite Tarzan', 5),
#  ('Virginian Pluto', 8),
#  ('Expecations Natural', 3),
#  ('North Tequila', 5),
#  ('Oleander Clue', 10),
#  ('Anaconda Confessions', 5),
#  ('Chicago North', 8),
#  ('Circus Youth', 2),
#  ('Secret Groundhog', 3),
#  ('Murder Antitrust', 8),
#  ('Nemo Campus', 5),
#  ('Beauty Grease', 5),
#  ('Slipper Fidelity', 7),
#  ('Road Roxanne', 8),
#  ('Right Cranes', 7),
#  ('Intolerable Intentions', 6),
#  ('River Outlaw', 4),
#  ('Idaho Love', 6),
#  ('Detective Vision', 3),
#  ('Balloon Homeward', 6),
#  ('Christmas Moonshine', 3),
#  ('Mockingbird Hollywood', 3),
#  ('Lover Truman', 7),
#  ('Gathering Calendar', 3),
#  ('Drums Dynamite', 7),
#  ('Samurai Lion', 2),
#  ('Pond Seattle', 3),
#  ('Pearl Destiny', 4)]

# %%
# сколько копии фильмов со словом SUPER в названии есть в наличии
con.execute("""
SELECT title, COUNT(inventory_id) FROM film f
JOIN inventory i ON f.film_id = i.film_id
WHERE title LIKE '%%Super%%'
GROUP BY title;
""").fetchall()
# Out:
# [('Casablanca Super', 5),
#  ('Shootist Superfly', 7),
#  ('Superfly Trip', 3),
#  ('Super Wyoming', 4)]

# %%
# выведем список покупателей с количеством их покупок в порядке убывания
con.execute("""
SELECT c.last_name ls, COUNT(p.amount) amount FROM customer c
LEFT JOIN payment p ON c.customer_id = p.customer_id
GROUP BY c.last_name
ORDER BY amount DESC;
""").fetchall()
# Out:
# [('Hunt', 45),
#  ('Seal', 42),
#  ('Shaw', 40),
#  ('Sanders', 39),
#  ('Snyder', 39),
#  ('Dean', 39),
#  ('Irby', 38),
#  ('Kennedy', 38),
#  ('Collazo', 37),
#  ('Huey', 36),
#  ('Hernandez', 35),
#  ('Brown', 35),
#  ('Brinson', 35),
#  ('Bull', 35),
#  ('Gonzalez', 34),
#  ('Porter', 34),
#  ('King', 34),
#  ('Quintanilla', 34),
#  ('Cary', 34),
#  ('Douglas', 34),
#  ('Leone', 34),
#  ('Butler', 34),
#  ('Way', 33),
#  ('Montgomery', 33),
#  ('Bradley', 33),
#  ('Ward', 33),
#  ('Ngo', 33),
#  ('Wade', 33),
#  ('Fennell', 33),
#  ('Madrigal', 32),
#  ('Boudreau', 32),
#  ('Mccarter', 32),
#  ('Clark', 32),
#  ('Larson', 32),
#  ('Long', 32),
#  ('Harris', 32),
#  ('Kelley', 32),
#  ('Havens', 32),
#  ('Warren', 32),
#  ('Mena', 32),
#  ('Hall', 32),
#  ('Carroll', 32),
#  ('Berry', 32),
#  ('Martino', 32),
#  ('Gresham', 32),
#  ('Peters', 32),
#  ('Mackenzie', 32),
#  ('Robertson', 32),
#  ('Wood', 31),
#  ('George', 31),
#  ('Campbell', 31),
#  ('Barfield', 31),
#  ('Sherrod', 31),
#  ('Olivares', 31),
#  ('Heaton', 31),
#  ('Marshall', 31),
#  ('Renner', 31),
#  ('Gilbert', 31),
#  ('Brownlee', 31),
#  ('Allard', 31),
#  ('Westmoreland', 31),
#  ('Schmidt', 31),
#  ('Arce', 31),
#  ('Webb', 31),
#  ('Runyon', 31),
#  ('Austin', 31),
#  ('Reyes', 31),
#  ('Ortiz', 30),
#  ('Simpkins', 30),
#  ('Ross', 30),
#  ('Oliver', 30),
#  ('Ellis', 30),
#  ('Allen', 30),
#  ('Collins', 30),
#  ('Silva', 30),
#  ('Green', 30),
#  ('Milam', 30),
#  ('Smith', 30),
#  ('Lovelace', 30),
#  ('Cox', 30),
#  ('Tucker', 30),
#  ('Rea', 30),
#  ('Jensen', 30),
#  ('Murray', 30),
#  ('Cornwell', 30),
#  ('Perry', 30),
#  ('Choate', 30),
#  ('Willis', 30),
#  ('Hanson', 30),
#  ('Young', 30),
#  ('Vargas', 30),
#  ('Stewart', 30),
#  ('Schofield', 30),
#  ('Ford', 30),
#  ('Tubbs', 30),
#  ('Salisbury', 30),
#  ('East', 30),
#  ('Stone', 30),
#  ('Milner', 29),
#  ('Bustamante', 29),
#  ('Pierce', 29),
#  ('Flores', 29),
#  ('Hite', 29),
#  ('Linton', 29),
#  ('Frazier', 29),
#  ('Hamilton', 29),
#  ('Rose', 29),
#  ('Poulin', 29),
#  ('Perez', 29),
#  ('Spurlock', 29),
#  ('Causey', 29),
#  ('Nelson', 29),
#  ('Scroggins', 29),
#  ('Roush', 29),
#  ('Fox', 29),
#  ('Gunderson', 29),
#  ('Outlaw', 29),
#  ('Spencer', 29),
#  ('Chapman', 29),
#  ('Fultz', 29),
#  ('Archuleta', 29),
#  ('Lawton', 29),
#  ('Seward', 28),
#  ('Schrader', 28),
#  ('Culp', 28),
#  ('Mason', 28),
#  ('Tobias', 28),
#  ('James', 28),
#  ('Gilliland', 28),
#  ('Terry', 28),
#  ('Patterson', 28),
#  ('Guillen', 28),
#  ('Box', 28),
#  ('Woods', 28),
#  ('Whiting', 28),
#  ('Hidalgo', 28),
#  ('Kowalski', 28),
#  ('Eggleston', 28),
#  ('Tan', 28),
#  ('Cole', 28),
#  ('Banda', 28),
#  ('Pinson', 28),
#  ('Castillo', 28),
#  ('Washington', 28),
#  ('Devore', 28),
#  ('Barclay', 28),
#  ('Romero', 28),
#  ('Bates', 28),
#  ('Lowe', 28),
#  ('Elrod', 28),
#  ('Morrell', 28),
#  ('Miller', 28),
#  ('Reynolds', 28),
#  ('Sanchez', 28),
#  ('Crawford', 28),
#  ('Deloach', 28),
#  ('Vu', 27),
#  ('Morrison', 27),
#  ('Teel', 27),
#  ('Lewis', 27),
#  ('Breaux', 27),
#  ('Ocampo', 27),
#  ('Dunn', 27),
#  ('Hicks', 27),
#  ('Arsenault', 27),
#  ('Larue', 27),
#  ('Payne', 27),
#  ('Walker', 27),
#  ('Bowens', 27),
#  ('Cheatham', 27),
#  ('Sledge', 27),
#  ('Fisher', 27),
#  ('Gardiner', 27),
#  ('Quigley', 27),
#  ('Gavin', 27),
#  ('Davidson', 27),
#  ('Jackson', 27),
#  ('Harrison', 27),
#  ('Prewitt', 27),
#  ('Robinson', 27),
#  ('Jennings', 27),
#  ('Alexander', 27),
#  ('Vasquez', 27),
#  ('Rice', 27),
#  ('Riley', 27),
#  ('Murrell', 27),
#  ('Holmes', 27),
#  ('Dixon', 27),
#  ('Williamson', 27),
#  ('Blakely', 27),
#  ('Watson', 27),
#  ('Grant', 27),
#  ('Betancourt', 27),
#  ('Gaither', 27),
#  ('Nettles', 27),
#  ('Ray', 27),
#  ('Vest', 27),
#  ('Hopkins', 27),
#  ('Silverman', 26),
#  ('Wright', 26),
#  ('Rapp', 26),
#  ('Carlson', 26),
#  ('Tomlin', 26),
#  ('Fortner', 26),
#  ('Shanks', 26),
#  ('Qualls', 26),
#  ('Rogers', 26),
#  ('Carter', 26),
#  ('Herrera', 26),
#  ('Malcolm', 26),
#  ('Day', 26),
#  ('Cook', 26),
#  ('Ratcliff', 26),
#  ('Motley', 26),
#  ('Thomas', 26),
#  ('Gutierrez', 26),
#  ('Phillips', 26),
#  ('Crawley', 26),
#  ('Johnson', 26),
#  ('Kelly', 26),
#  ('Morgan', 26),
#  ('Grey', 26),
#  ('Simmons', 26),
#  ('Rhodes', 26),
#  ('Hart', 26),
#  ('Johnston', 26),
#  ('Lawson', 26),
#  ('Lopez', 26),
#  ('Gibson', 26),
#  ('Casillas', 26),
#  ('Farnsworth', 26),
#  ('Poindexter', 26),
#  ('Vines', 26),
#  ('Sauer', 26),
#  ('Robins', 26),
#  ('Greco', 25),
#  ('Martin', 25),
#  ('Black', 25),
#  ('Fuller', 25),
#  ('Simpson', 25),
#  ('Harder', 25),
#  ('Gamez', 25),
#  ('Howell', 25),
#  ('Mcwhorter', 25),
#  ('Nguyen', 25),
#  ('Armstrong', 25),
#  ('Wheeler', 25),
#  ('Weaver', 25),
#  ('Cromwell', 25),
#  ('Gillette', 25),
#  ('Robb', 25),
#  ('Hawks', 25),
#  ('Mattox', 25),
#  ('Richardson', 25),
#  ('Wagner', 25),
#  ('Adams', 25),
#  ('Hurtado', 25),
#  ('Mahan', 25),
#  ('Palmer', 25),
#  ('Gomez', 25),
#  ('Stanley', 25),
#  ('Ellington', 25),
#  ('Herrmann', 25),
#  ('Owens', 25),
#  ('Brewer', 25),
#  ('Sikes', 25),
#  ('May', 25),
#  ('Kahn', 25),
#  ('Mitchell', 25),
#  ('Adam', 25),
#  ('Barnett', 25),
#  ('Kinder', 25),
#  ('Alvarez', 25),
#  ('Holland', 25),
#  ('Wofford', 25),
#  ('Still', 25),
#  ('Davis', 25),
#  ('Bales', 25),
#  ('Henry', 25),
#  ('Perryman', 24),
#  ('Mccurdy', 24),
#  ('Murphy', 24),
#  ('Perkins', 24),
#  ('Baugh', 24),
#  ('Harvey', 24),
#  ('Hardison', 24),
#  ('Knott', 24),
#  ('Carbone', 24),
#  ('Edwards', 24),
#  ('Bell', 24),
#  ('Williams', 24),
#  ('Banks', 24),
#  ('Buford', 24),
#  ('Olson', 24),
#  ('Power', 24),
#  ('Bess', 24),
#  ('Holm', 24),
#  ('Scott', 24),
#  ('Knight', 24),
#  ('Stanfield', 24),
#  ('Ricketts', 24),
#  ('Hannon', 24),
#  ('Vanhorn', 24),
#  ('Mcalister', 24),
#  ('Meehan', 24),
#  ('Burleson', 24),
#  ('Rodriquez', 24),
#  ('Taylor', 24),
#  ('Jimenez', 24),
#  ('Coleman', 24),
#  ('Sanborn', 24),
#  ('Asher', 24),
#  ('Nichols', 24),
#  ('Oglesby', 24),
#  ('Fleming', 24),
#  ('Noe', 24),
#  ('Currier', 24),
#  ('Lucas', 24),
#  ('Swafford', 24),
#  ('Lane', 24),
#  ('Morris', 24),
#  ('Shelton', 24),
#  ('Griffin', 24),
#  ('Franklin', 24),
#  ('Forman', 24),
#  ('Jordon', 24),
#  ('Barrett', 23),
#  ('Gray', 23),
#  ('Hayes', 23),
#  ('Rhoads', 23),
#  ('Ralston', 23),
#  ('Anderson', 23),
#  ('Welch', 23),
#  ('Elliott', 23),
#  ('Waggoner', 23),
#  ('Freeman', 23),
#  ('Reid', 23),
#  ('Howland', 23),
#  ('Rico', 23),
#  ('Foust', 23),
#  ('Newsom', 23),
#  ('Arnold', 23),
#  ('Jacobs', 23),
#  ('Duncan', 23),
#  ('Kim', 23),
#  ('Graf', 23),
#  ('Ferguson', 23),
#  ('White', 23),
#  ('Martel', 23),
#  ('Hiatt', 23),
#  ('Mckinney', 23),
#  ('Lynch', 23),
#  ('Churchill', 23),
#  ('Mccartney', 23),
#  ('Burke', 23),
#  ('Lee', 23),
#  ('Watts', 23),
#  ('Burns', 23),
#  ('Douglass', 23),
#  ('Graves', 23),
#  ('South', 23),
#  ('Easter', 23),
#  ('Bennett', 23),
#  ('Diaz', 23),
#  ('Hale', 23),
#  ('Shelby', 23),
#  ('Duggan', 23),
#  ('Waugh', 23),
#  ('Sutton', 23),
#  ('Myers', 23),
#  ('Thorn', 23),
#  ('Talbert', 23),
#  ('Pitt', 23),
#  ('Bone', 23),
#  ('Wilson', 23),
#  ('Forsythe', 22),
#  ('Windham', 22),
#  ('Jenkins', 22),
#  ('Gregory', 22),
#  ('Peterson', 22),
#  ('Stevens', 22),
#  ('Jung', 22),
#  ('Burton', 22),
#  ('Jones', 22),
#  ('Francisco', 22),
#  ('Slone', 22),
#  ('Crouse', 22),
#  ('Mcduffie', 22),
#  ('Fields', 22),
#  ('Schilling', 22),
#  ('Brooks', 22),
#  ('Gaffney', 22),
#  ('Lawrence', 22),
#  ('Chestnut', 22),
#  ('Estep', 22),
#  ('Mauldin', 22),
#  ('Lambert', 22),
#  ('Hunter', 22),
#  ('Ashcraft', 22),
#  ('Millard', 22),
#  ('Chisholm', 22),
#  ('Byrd', 22),
#  ('Varney', 22),
#  ('Delvalle', 22),
#  ('Pullen', 22),
#  ('Robert', 22),
#  ('Purdy', 22),
#  ('Chambers', 22),
#  ('Barkley', 22),
#  ('Roberts', 22),
#  ('Cunningham', 22),
#  ('Pfeiffer', 22),
#  ('Coy', 22),
#  ('Ebert', 22),
#  ('Wiles', 22),
#  ('Andrews', 22),
#  ('Moeller', 22),
#  ('Mark', 22),
#  ('Meyer', 22),
#  ('Sullivan', 22),
#  ('Miles', 22),
#  ('Benner', 22),
#  ('Deluca', 22),
#  ('Garza', 22),
#  ('Markham', 22),
#  ('Harkins', 22),
#  ('Menard', 22),
#  ('Bailey', 22),
#  ('Graham', 22),
#  ('Daniels', 22),
#  ('Troutman', 21),
#  ('Colby', 21),
#  ('Carpenter', 21),
#  ('Horton', 21),
#  ('Artis', 21),
#  ('Bostic', 21),
#  ('Henderson', 21),
#  ('Walters', 21),
#  ('Powell', 21),
#  ('Coughlin', 21),
#  ('Henning', 21),
#  ('Little', 21),
#  ('Barbee', 21),
#  ('Soto', 21),
#  ('Skidmore', 21),
#  ('Turner', 21),
#  ('Schwarz', 21),
#  ('Gannon', 21),
#  ('Fraley', 21),
#  ('Cooper', 21),
#  ('Fletcher', 21),
#  ('Price', 21),
#  ('Bishop', 21),
#  ('Wallace', 21),
#  ('Weiner', 21),
#  ('Pena', 21),
#  ('Lumpkin', 21),
#  ('Wheat', 21),
#  ('Paine', 21),
#  ('Baker', 21),
#  ('Stepp', 21),
#  ('Nolen', 20),
#  ('Bolin', 20),
#  ('Moore', 20),
#  ('Houle', 20),
#  ('Pemberton', 20),
#  ('Lance', 20),
#  ('Castro', 20),
#  ('Selby', 20),
#  ('Stephens', 20),
#  ('Gilman', 20),
#  ('Torres', 20),
#  ('Richards', 20),
#  ('Harper', 20),
#  ('Rinehart', 20),
#  ('Waldrop', 20),
#  ('Ruiz', 20),
#  ('Mccrary', 20),
#  ('Bourque', 20),
#  ('Cruz', 20),
#  ('Gordon', 20),
#  ('Joy', 20),
#  ('Burk', 20),
#  ('Foster', 20),
#  ('Hill', 20),
#  ('Hughes', 20),
#  ('Matthews', 20),
#  ('Hoffman', 20),
#  ('Brothers', 20),
#  ('Olvera', 20),
#  ('Emmons', 20),
#  ('Mcadams', 20),
#  ('Marlow', 20),
#  ('Herzog', 20),
#  ('Guajardo', 20),
#  ('Neumann', 20),
#  ('Gooch', 20),
#  ('Howard', 20),
#  ('Morrissey', 19),
#  ('Kruger', 19),
#  ('Yanez', 19),
#  ('Satterfield', 19),
#  ('Carranza', 19),
#  ('Grigsby', 19),
#  ('West', 19),
#  ('Gonzales', 19),
#  ('Turpin', 19),
#  ('Dowd', 19),
#  ('Hauser', 19),
#  ('Medina', 19),
#  ('Royal', 19),
#  ('Noland', 19),
#  ('Garrett', 19),
#  ('Geary', 19),
#  ('Boyd', 19),
#  ('Grissom', 19),
#  ('Lyman', 19),
#  ('Watkins', 19),
#  ('Barnes', 19),
#  ('Craig', 19),
#  ('Sims', 19),
#  ('Curley', 19),
#  ('Garcia', 19),
#  ('Thrasher', 19),
#  ('Moreno', 19),
#  ('Ryan', 19),
#  ('Yee', 19),
#  ('Reed', 19),
#  ('Rodriguez', 19),
#  ('Wren', 19),
#  ('Curtis', 19),
#  ('Parker', 19),
#  ('Truong', 19),
#  ('Meador', 19),
#  ('Mills', 19),
#  ('Abney', 19),
#  ('Pearson', 18),
#  ('Clary', 18),
#  ('Culpepper', 18),
#  ('Cintron', 18),
#  ('Fortier', 18),
#  ('Mccoy', 18),
#  ('Mendoza', 18),
#  ('Isom', 18),
#  ('Carr', 18),
#  ('Andrew', 18),
#  ('Martinez', 18),
#  ('Gruber', 18),
#  ('Shelley', 18),
#  ('Thompson', 18),
#  ('Russell', 18),
#  ('Bunn', 18),
#  ('Greene', 18),
#  ('Ramos', 18),
#  ('Ramirez', 17),
#  ('Holt', 17),
#  ('Chapa', 17),
#  ('Butterfield', 17),
#  ('Hawkins', 17),
#  ('Mcdonald', 17),
#  ('Stclair', 17),
#  ('Schuler', 17),
#  ('Lombardi', 17),
#  ('Scarborough', 17),
#  ('Hudson', 17),
#  ('Aquino', 17),
#  ('Spear', 17),
#  ('Bryant', 17),
#  ('Ely', 17),
#  ('Christenson', 16),
#  ('Hansen', 16),
#  ('Mahon', 16),
#  ('Fernandez', 16),
#  ('Neal', 16),
#  ('Cornish', 16),
#  ('Tirado', 16),
#  ('Gandy', 16),
#  ('Billingsley', 16),
#  ('Isbell', 16),
#  ('Chavez', 16),
#  ('Fowler', 15),
#  ('Baughman', 15),
#  ('Schwab', 15),
#  ('Meek', 15),
#  ('Kraus', 15),
#  ('Gardner', 15),
#  ('Trout', 15),
#  ('Wells', 14),
#  ('Evans', 14),
#  ('Kenyon', 14),
#  ('Gooden', 14),
#  ('Morales', 14),
#  ('Caldwell', 13),
#  ('Rivera', 13),
#  ('Bowman', 13),
#  ('Cabral', 13),
#  ('Jordan', 12),
#  ('Obrien', 10),
#  ('Wyman', 7)]

# %%
# выведем имена и почтовые адреса всех покупателей из России
con.execute("""
SELECT last_name, first_name, email FROM customer c
JOIN address a ON c.address_id = a.address_id
JOIN city ON a.city_id = city.city_id
JOIN country co ON city.country_id = co.country_id
WHERE country = 'Russian Federation';
""").fetchall()
# Out:
# [('Schrader', 'Jimmy', 'jimmy.schrader@sakilacustomer.org'),
#  ('Reed', 'Doris', 'doris.reed@sakilacustomer.org'),
#  ('Houle', 'Ray', 'ray.houle@sakilacustomer.org'),
#  ('Thompson', 'Donna', 'donna.thompson@sakilacustomer.org'),
#  ('Wallace', 'Connie', 'connie.wallace@sakilacustomer.org'),
#  ('Hansen', 'Delores', 'delores.hansen@sakilacustomer.org'),
#  ('Hayes', 'Robin', 'robin.hayes@sakilacustomer.org'),
#  ('Baughman', 'Robert', 'robert.baughman@sakilacustomer.org'),
#  ('Easter', 'Ben', 'ben.easter@sakilacustomer.org'),
#  ('Hart', 'Dana', 'dana.hart@sakilacustomer.org'),
#  ('Bates', 'Daisy', 'daisy.bates@sakilacustomer.org'),
#  ('Causey', 'Philip', 'philip.causey@sakilacustomer.org'),
#  ('Gaither', 'Randy', 'randy.gaither@sakilacustomer.org'),
#  ('Trout', 'Paul', 'paul.trout@sakilacustomer.org'),
#  ('Turner', 'Marie', 'marie.turner@sakilacustomer.org'),
#  ('Dunn', 'Erin', 'erin.dunn@sakilacustomer.org'),
#  ('Simpkins', 'Arthur', 'arthur.simpkins@sakilacustomer.org'),
#  ('Campbell', 'Catherine', 'catherine.campbell@sakilacustomer.org'),
#  ('Bowens', 'Clifford', 'clifford.bowens@sakilacustomer.org'),
#  ('Evans', 'Ann', 'ann.evans@sakilacustomer.org'),
#  ('Greene', 'Jeanette', 'jeanette.greene@sakilacustomer.org'),
#  ('Poindexter', 'Hector', 'hector.poindexter@sakilacustomer.org'),
#  ('Mcadams', 'Alfredo', 'alfredo.mcadams@sakilacustomer.org'),
#  ('Stevens', 'Elaine', 'elaine.stevens@sakilacustomer.org'),
#  ('Kruger', 'Herbert', 'herbert.kruger@sakilacustomer.org'),
#  ('Fraley', 'Juan', 'juan.fraley@sakilacustomer.org'),
#  ('Sherrod', 'Warren', 'warren.sherrod@sakilacustomer.org'),
#  ('Foust', 'Jack', 'jack.foust@sakilacustomer.org')]

# %%
# фильмы, которые берут в прокат чаще всего
con.execute("""
SELECT title, COUNT(r.inventory_id) count FROM film f
JOIN inventory i ON f.film_id = i.film_id
JOIN rental r ON i.inventory_id = r.inventory_id
GROUP BY f.title
ORDER BY count DESC;
""").fetchall()
# Out:
# [('Bucket Brotherhood', 34),
#  ('Rocketeer Mother', 33),
#  ('Juggler Hardly', 32),
#  ('Scalawag Duck', 32),
#  ('Grit Clockwork', 32),
#  ('Forward Temple', 32),
#  ('Ridgemont Submarine', 32),
#  ('Goodfellas Salute', 31),
#  ('Zorro Ark', 31),
#  ('Hobbit Alien', 31),
#  ('Robbers Joon', 31),
#  ('Timberland Sky', 31),
#  ('Rush Goodfellas', 31),
#  ('Network Peak', 31),
#  ('Wife Turn', 31),
#  ('Apache Divine', 31),
#  ('Massacre Usual', 30),
#  ('Harry Idaho', 30),
#  ('Rugrats Shakespeare', 30),
#  ('Dogma Family', 30),
#  ('English Bulworth', 30),
#  ('Suspects Quills', 30),
#  ('Cat Coneheads', 30),
#  ('Butterfly Chocolat', 30),
#  ('Pulp Beverly', 30),
#  ('Married Go', 30),
#  ('Graffiti Love', 30),
#  ('Frost Head', 30),
#  ('Witches Panic', 30),
#  ('Idols Snatchers', 30),
#  ('Muscle Bright', 30),
#  ('Shock Cabin', 30),
#  ('Titans Jerk', 29),
#  ('Virginian Pluto', 29),
#  ('Family Sweet', 29),
#  ('Enemy Odds', 29),
#  ('Deer Virginian', 29),
#  ('Greatest North', 29),
#  ('Confidential Interview', 29),
#  ('Storm Happiness', 29),
#  ('Bingo Talented', 29),
#  ('Videotape Arsenic', 29),
#  ('Boogie Amelie', 29),
#  ('Moon Bunch', 29),
#  ('Sweethearts Suspects', 29),
#  ('Gleaming Jawbreaker', 29),
#  ('Talented Homicide', 29),
#  ('Story Side', 28),
#  ('Closer Bang', 28),
#  ('Trip Newton', 28),
#  ('Fatal Haunted', 28),
#  ('Giant Troopers', 28),
#  ('Expendable Stallion', 28),
#  ('Roses Treasure', 28),
#  ('Voyage Legally', 28),
#  ('Handicap Boondock', 28),
#  ('Gilmore Boiled', 28),
#  ('Saturday Lambs', 28),
#  ('Torque Bound', 27),
#  ('Forrester Comancheros', 27),
#  ('Dancing Fever', 27),
#  ('Movie Shakespeare', 27),
#  ('Horror Reign', 27),
#  ('Operation Operation', 27),
#  ('Dorado Notting', 27),
#  ('Goldmine Tycoon', 27),
#  ('Princess Giant', 27),
#  ('Lose Inch', 27),
#  ('Gangs Pride', 27),
#  ('Wardrobe Phantom', 27),
#  ('Lies Treatment', 27),
#  ('Blackout Private', 27),
#  ('Telegraph Voyage', 27),
#  ('Detective Vision', 27),
#  ('Spy Mile', 27),
#  ('Invasion Cyclone', 27),
#  ('Curtain Videotape', 27),
#  ('None Spiking', 27),
#  ('Camelot Vacation', 27),
#  ('Primary Glass', 27),
#  ('Range Moonwalker', 27),
#  ('Swarm Gold', 27),
#  ('Loathing Legally', 27),
#  ('Chance Resurrection', 27),
#  ('Disturbing Scarface', 26),
#  ('Metropolis Coma', 26),
#  ('Tracy Cider', 26),
#  ('Pelican Comforts', 26),
#  ('Innocent Usual', 26),
#  ('Seabiscuit Punk', 26),
#  ('Brotherhood Blanket', 26),
#  ('Pocus Pulp', 26),
#  ('Tights Dawn', 26),
#  ('Stagecoach Armageddon', 26),
#  ('Malkovich Pet', 26),
#  ('Fellowship Autumn', 26),
#  ('Alaska Phantom', 26),
#  ('Island Exorcist', 26),
#  ('Durham Panky', 26),
#  ('Fantasy Troopers', 26),
#  ('Half Outfield', 26),
#  ('Hyde Doctor', 26),
#  ('Coma Head', 26),
#  ('Contact Anonymous', 26),
#  ('Hanky October', 26),
#  ('Velvet Terminator', 26),
#  ('Pity Bound', 26),
#  ('Westward Seabiscuit', 26),
#  ('Clash Freddy', 25),
#  ('Samurai Lion', 25),
#  ('Working Microcosmos', 25),
#  ('Clueless Bucket', 25),
#  ('Oscar Gold', 25),
#  ('Sun Confessions', 25),
#  ('Fish Opus', 25),
#  ('Madness Attacks', 25),
#  ('Downhill Enough', 25),
#  ('Coneheads Smoochy', 25),
#  ('Barbarella Streetcar', 25),
#  ('Trading Pinocchio', 25),
#  ('Feud Frogmen', 25),
#  ('Streetcar Intentions', 25),
#  ('Nightmare Chill', 25),
#  ('Tomorrow Hustler', 25),
#  ('Dynamite Tarzan', 25),
#  ('Mallrats United', 25),
#  ('Show Lord', 25),
#  ('Escape Metropolis', 25),
#  ('Effect Gladiator', 25),
#  ('Double Wrath', 25),
#  ('Telemark Heartbreakers', 25),
#  ('Hills Neighbors', 25),
#  ('Academy Dinosaur', 25),
#  ('Metal Armageddon', 25),
#  ('Shepherd Midsummer', 25),
#  ('Gun Bonnie', 25),
#  ('Jason Trap', 24),
#  ('Lola Agent', 24),
#  ('Bound Cheaper', 24),
#  ('Maiden Home', 24),
#  ('Sunrise League', 24),
#  ('Mockingbird Hollywood', 24),
#  ('Sleeping Suspects', 24),
#  ('Slums Duck', 24),
#  ('Fargo Gandhi', 24),
#  ('Attraction Newton', 24),
#  ('Caper Motions', 24),
#  ('Orange Grapes', 24),
#  ('Goldfinger Sensibility', 24),
#  ('Celebrity Horn', 24),
#  ('Shootist Superfly', 24),
#  ('Hurricane Affair', 24),
#  ('Atlantis Cause', 24),
#  ('Drifter Commandments', 24),
#  ('Color Philadelphia', 24),
#  ('Horn Working', 24),
#  ('Oz Liaisons', 24),
#  ('Strangelove Desire', 24),
#  ('Gunfight Moon', 24),
#  ('Alamo Videotape', 24),
#  ('Wedding Apollo', 24),
#  ('Arachnophobia Rollercoaster', 24),
#  ('Center Dinosaur', 24),
#  ('Ice Crossing', 24),
#  ('Seattle Expecations', 24),
#  ('Jumping Wrath', 24),
#  ('Roman Punk', 24),
#  ('Pacific Amistad', 24),
#  ('Knock Warlock', 24),
#  ('Kwai Homeward', 23),
#  ('Truman Crazy', 23),
#  ('Women Dorado', 23),
#  ('Strictly Scarface', 23),
#  ('Fool Mockingbird', 23),
#  ('Wash Heavenly', 23),
#  ('Candles Grapes', 23),
#  ('Snowman Rollercoaster', 23),
#  ('Wind Phantom', 23),
#  ('Heavyweights Beast', 23),
#  ('Balloon Homeward', 23),
#  ('Salute Apollo', 23),
#  ('Murder Antitrust', 23),
#  ('Yentl Idaho', 23),
#  ('Gentlemen Stage', 23),
#  ('Aladdin Calendar', 23),
#  ('Name Detective', 23),
#  ('Earth Vision', 23),
#  ('Affair Prejudice', 23),
#  ('Titanic Boondock', 23),
#  ('Philadelphia Wife', 23),
#  ('House Dynamite', 23),
#  ('Easy Gladiator', 23),
#  ('Cupboard Sinners', 23),
#  ('Others Soup', 23),
#  ('Outbreak Divine', 23),
#  ('Patton Interview', 23),
#  ('Carrie Bunch', 23),
#  ('Scorpion Apollo', 23),
#  ('Steel Santa', 23),
#  ('Freddy Storm', 23),
#  ('Flamingos Connecticut', 23),
#  ('Crooked Frogmen', 23),
#  ('Trouble Date', 23),
#  ('Karate Moon', 23),
#  ('American Circus', 22),
#  ('Sinners Atlantis', 22),
#  ('Falcon Volume', 22),
#  ('Maltese Hope', 22),
#  ('Eagles Panky', 22),
#  ('Fight Jawbreaker', 22),
#  ('Tourist Pelican', 22),
#  ('Volcano Texas', 22),
#  ('Packer Madigan', 22),
#  ('Chicken Hellfighters', 22),
#  ('Liaisons Sweet', 22),
#  ('Beauty Grease', 22),
#  ('Chill Luck', 22),
#  ('Alien Center', 22),
#  ('Shakespeare Saddle', 22),
#  ('Borrowers Bedazzled', 22),
#  ('Grapes Fury', 22),
#  ('Head Stranger', 22),
#  ('Wonderland Christmas', 22),
#  ('Whisperer Giant', 22),
#  ('Bear Graceland', 22),
#  ('High Encino', 22),
#  ('Congeniality Quest', 22),
#  ('South Wait', 22),
#  ('Dream Pickup', 22),
#  ('Hustler Party', 22),
#  ('Midsummer Groundhog', 22),
#  ('Flatliners Killer', 22),
#  ('Haunting Pianist', 22),
#  ('Kiss Glory', 22),
#  ('Homicide Peach', 22),
#  ('Sea Virgin', 22),
#  ('Annie Identity', 22),
#  ('Angels Life', 22),
#  ('Alter Victory', 22),
#  ('Queen Luke', 22),
#  ('Blade Polish', 22),
#  ('Banger Pinocchio', 22),
#  ('Snatch Slipper', 22),
#  ('Berets Agent', 21),
#  ('Moonshine Cabin', 21),
#  ('Grease Youth', 21),
#  ('Crossroads Casualties', 21),
#  ('Highball Potter', 21),
#  ('Christmas Moonshine', 21),
#  ('Anaconda Confessions', 21),
#  ('Deceiver Betrayed', 21),
#  ('Basic Easy', 21),
#  ('Driving Polish', 21),
#  ('Unbreakable Karate', 21),
#  ('Empire Malkovich', 21),
#  ('Calendar Gunfight', 21),
#  ('Mourning Purple', 21),
#  ('Open African', 21),
#  ('Fidelity Devil', 21),
#  ('Divide Monster', 21),
#  ('Wait Cider', 21),
#  ('Doom Dancing', 21),
#  ('Amadeus Holy', 21),
#  ('Undefeated Dalmations', 21),
#  ('Sting Personal', 21),
#  ('Beverly Outlaw', 21),
#  ('Cause Date', 21),
#  ('Amistad Midsummer', 21),
#  ('Blues Instinct', 21),
#  ('Pianist Outfield', 21),
#  ('Splendor Patton', 21),
#  ('Egg Igby', 21),
#  ('Sleepy Japanese', 21),
#  ('Wolves Desire', 21),
#  ('Sleuth Orient', 21),
#  ('Badman Dawn', 21),
#  ('Dracula Crystal', 21),
#  ('Suit Walls', 21),
#  ('Armageddon Lost', 21),
#  ('Vacation Boondock', 21),
#  ('Fireball Philadelphia', 21),
#  ('Brooklyn Desert', 21),
#  ('Pirates Roxanne', 21),
#  ('Arizona Bang', 21),
#  ('Ghost Groundhog', 21),
#  ('Sabrina Midnight', 21),
#  ('Secret Groundhog', 21),
#  ('Chainsaw Uptown', 21),
#  ('Resurrection Silverado', 21),
#  ('Coast Rainbow', 21),
#  ('Lebowski Soldiers', 21),
#  ('Chariots Conspiracy', 21),
#  ('Agent Truman', 21),
#  ('Excitement Eve', 21),
#  ('Star Operation', 21),
#  ('Sleepless Monsoon', 20),
#  ('Hellfighters Sierra', 20),
#  ('Garden Island', 20),
#  ('Bringing Hysterical', 20),
#  ('Secrets Paradise', 20),
#  ('Peak Forever', 20),
#  ('River Outlaw', 20),
#  ('Chasing Fight', 20),
#  ('Straight Hours', 20),
#  ('Flying Hook', 20),
#  ('Spice Sorority', 20),
#  ('Dalmations Sweden', 20),
#  ('Harper Dying', 20),
#  ('Million Ace', 20),
#  ('Intrigue Worst', 20),
#  ('Masked Bubble', 20),
#  ('Jerk Paycheck', 20),
#  ('Insider Arizona', 20),
#  ('Quest Mussolini', 20),
#  ('Stepmom Dream', 20),
#  ('Minds Truman', 20),
#  ('Go Purple', 20),
#  ('Interview Liaisons', 20),
#  ('Redemption Comforts', 20),
#  ('Dinosaur Secretary', 20),
#  ('Kissing Dolls', 20),
#  ('Pinocchio Simon', 20),
#  ('Money Harold', 20),
#  ('Room Roman', 20),
#  ('Reunion Witches', 20),
#  ('Prejudice Oleander', 20),
#  ('Love Suicides', 20),
#  ('Chocolat Harry', 20),
#  ('Tramp Others', 20),
#  ('Wrong Behavior', 20),
#  ('Hunchback Impossible', 20),
#  ('Outfield Massacre', 20),
#  ('Cheaper Clyde', 20),
#  ('Heartbreakers Bright', 20),
#  ('Kick Savannah', 20),
#  ('Northwest Polish', 20),
#  ('Jet Neighbors', 20),
#  ('Reign Gentlemen', 20),
#  ('Neighbors Charade', 19),
#  ('Sundance Invasion', 19),
#  ('Shawshank Bubble', 19),
#  ('Canyon Stock', 19),
#  ('Patient Sister', 19),
#  ('Encounters Curtain', 19),
#  ('Hours Rage', 19),
#  ('Requiem Tycoon', 19),
#  ('National Story', 19),
#  ('Earring Instinct', 19),
#  ('Doors President', 19),
#  ('Details Packer', 19),
#  ('Road Roxanne', 19),
#  ('Music Boondock', 19),
#  ('Igby Maker', 19),
#  ('Honey Ties', 19),
#  ('Fiction Christmas', 19),
#  ('Eyes Driving', 19),
#  ('Roxanne Rebel', 19),
#  ('Thief Pelican', 19),
#  ('Fantasia Park', 19),
#  ('Jedi Beneath', 19),
#  ('Fury Murder', 19),
#  ('Rage Games', 19),
#  ('Hanging Deep', 19),
#  ('Independence Hotel', 19),
#  ('Backlash Undefeated', 19),
#  ('Campus Remember', 19),
#  ('Disciple Mother', 19),
#  ('Bill Others', 19),
#  ('Cider Desire', 19),
#  ('Novocaine Flight', 19),
#  ('Club Graffiti', 19),
#  ('Bride Intrigue', 19),
#  ('Something Duck', 19),
#  ('Mine Titans', 19),
#  ('Desert Poseidon', 19),
#  ('Trojan Tomorrow', 19),
#  ('Pond Seattle', 19),
#  ('Clones Pinocchio', 19),
#  ('Gables Metropolis', 19),
#  ('Mars Roman', 19),
#  ('Voice Peach', 19),
#  ('Gorgeous Bingo', 19),
#  ('Encino Elf', 19),
#  ('Secretary Rouge', 18),
#  ('Expecations Natural', 18),
#  ('Unforgiven Zoolander', 18),
#  ('Driver Annie', 18),
#  ('Galaxy Sweethearts', 18),
#  ('Groundhog Uncut', 18),
#  ('Weekend Personal', 18),
#  ('Hope Tootsie', 18),
#  ('Dawn Pond', 18),
#  ('Paradise Sabrina', 18),
#  ('Inch Jet', 18),
#  ('Rouge Squad', 18),
#  ('Boulevard Mob', 18),
#  ('Forrest Sons', 18),
#  ('Smoking Barbarella', 18),
#  ('Birds Perdition', 18),
#  ('Sweden Shining', 18),
#  ('Mission Zoolander', 18),
#  ('Alone Trip', 18),
#  ('Lion Uncut', 18),
#  ('Heaven Freedom', 18),
#  ('Whale Bikini', 18),
#  ('Candidate Perdition', 18),
#  ('Wonka Sea', 18),
#  ('Barefoot Manchurian', 18),
#  ('Jade Bunch', 18),
#  ('Insects Stone', 18),
#  ('Dragonfly Strangers', 18),
#  ('Cleopatra Devil', 18),
#  ('Pollock Deliverance', 18),
#  ('Airport Pollock', 18),
#  ('Vanishing Rocky', 18),
#  ('Carol Texas', 18),
#  ('Polish Brooklyn', 18),
#  ('Enough Raging', 18),
#  ('Groove Fiction', 18),
#  ('Core Suit', 18),
#  ('Racer Egg', 18),
#  ('Jacket Frisco', 18),
#  ('Darn Forrester', 18),
#  ('Scarface Bang', 18),
#  ('Instinct Airport', 18),
#  ('Remember Diary', 18),
#  ('Sugar Wonka', 17),
#  ('Potter Connecticut', 17),
#  ('Joon Northwest', 17),
#  ('Rear Trading', 17),
#  ('Bikini Borrowers', 17),
#  ('Poseidon Forever', 17),
#  ('Roots Remember', 17),
#  ('Waterfront Deliverance', 17),
#  ('Greek Everyone', 17),
#  ('Lawless Vision', 17),
#  ('Ferris Mother', 17),
#  ('Flintstones Happiness', 17),
#  ('Newton Labyrinth', 17),
#  ('Factory Dragon', 17),
#  ('Jekyll Frogmen', 17),
#  ('Perfect Groove', 17),
#  ('Satisfaction Confidential', 17),
#  ('Holocaust Highball', 17),
#  ('Majestic Floats', 17),
#  ('Zoolander Fiction', 17),
#  ('Mask Peach', 17),
#  ('Egypt Tenenbaums', 17),
#  ('Lady Stage', 17),
#  ('Virgin Daisy', 17),
#  ('Taxi Kick', 17),
#  ('Teen Apollo', 17),
#  ('Jericho Mulan', 17),
#  ('United Pilot', 17),
#  ('Conversation Downhill', 17),
#  ('Orient Closer', 17),
#  ('Idaho Love', 17),
#  ('French Holiday', 17),
#  ('Intentions Empire', 17),
#  ('Comforts Rush', 17),
#  ('Confused Candles', 17),
#  ('Gandhi Kwai', 17),
#  ('Slacker Liaisons', 17),
#  ('Rock Instinct', 17),
#  ('Freaky Pocus', 17),
#  ('Midnight Westward', 17),
#  ('Dying Maker', 17),
#  ('Musketeers Wait', 17),
#  ('Breakfast Goldfinger', 17),
#  ('Noon Papi', 17),
#  ('Strangers Graffiti', 17),
#  ('League Hellfighters', 17),
#  ('Beach Heartbreakers', 17),
#  ('Louisiana Harry', 17),
#  ('Hanover Galaxy', 17),
#  ('Watch Tracy', 16),
#  ('Rules Human', 16),
#  ('Words Hunter', 16),
#  ('Motions Details', 16),
#  ('Indian Love', 16),
#  ('Artist Coldblooded', 16),
#  ('Homeward Cider', 16),
#  ('Caddyshack Jedi', 16),
#  ('Trap Guys', 16),
#  ('Varsity Trip', 16),
#  ('Quills Bull', 16),
#  ('Hall Cassidy', 16),
#  ('Rocky War', 16),
#  ('Casablanca Super', 16),
#  ('Bull Shawshank', 16),
#  ('Moulin Wake', 16),
#  ('Willow Tracy', 16),
#  ('Reap Unfaithful', 16),
#  ('Sagebrush Clueless', 16),
#  ('Pluto Oleander', 16),
#  ('Patriot Roman', 16),
#  ('Lock Rear', 16),
#  ('Graduate Lord', 16),
#  ('Bonnie Holocaust', 16),
#  ('Mermaid Insects', 16),
#  ('Dude Blindness', 16),
#  ('Wanda Chamber', 16),
#  ('Uprising Uptown', 16),
#  ('Worst Banger', 16),
#  ('Baked Cleopatra', 16),
#  ('Destiny Saturday', 16),
#  ('Summer Scarface', 16),
#  ('Creatures Shakespeare', 16),
#  ('Wizard Coldblooded', 16),
#  ('Daisy Menagerie', 16),
#  ('Pilot Hoosiers', 16),
#  ('Army Flintstones', 16),
#  ('Paycheck Wait', 16),
#  ('Chicago North', 16),
#  ('Coldblooded Darling', 16),
#  ('Attacks Hate', 16),
#  ('Slipper Fidelity', 16),
#  ('Pickup Driving', 16),
#  ('Pure Runner', 16),
#  ('West Lion', 16),
#  ('Gaslight Crusade', 16),
#  ('Streak Ridgemont', 16),
#  ('Pride Alamo', 16),
#  ('Jeepers Wedding', 16),
#  ('Craft Outfield', 16),
#  ('Mummy Creatures', 16),
#  ('Silence Kane', 16),
#  ('Command Darling', 16),
#  ('Conquerer Nuts', 16),
#  ('Human Graffiti', 15),
#  ('Lonely Elephant', 15),
#  ('Worker Tarzan', 15),
#  ('Necklace Outbreak', 15),
#  ('Loser Hustler', 15),
#  ('Entrapment Satisfaction', 15),
#  ('Cyclone Family', 15),
#  ('Cabin Flash', 15),
#  ('Translation Summer', 15),
#  ('Ship Wonderland', 15),
#  ('Nash Chocolat', 15),
#  ('Anthem Luke', 15),
#  ('Shrek License', 15),
#  ('Dirty Ace', 15),
#  ('Scissorhands Slums', 15),
#  ('Boiled Dares', 15),
#  ('Vietnam Smoochy', 15),
#  ('Panther Reds', 15),
#  ('Sons Interview', 15),
#  ('Modern Dorado', 15),
#  ('Sweet Brotherhood', 15),
#  ('Sierra Divide', 15),
#  ('Mosquito Armageddon', 15),
#  ('Spirit Flintstones', 15),
#  ('Odds Boogie', 15),
#  ('Edge Kissing', 15),
#  ('Siege Madre', 15),
#  ('Hunting Musketeers', 15),
#  ('Rings Heartbreakers', 15),
#  ('Divine Resurrection', 15),
#  ('Manchurian Curtain', 15),
#  ('Lust Lock', 15),
#  ('Tootsie Pilot', 15),
#  ('Submarine Bed', 15),
#  ('Airplane Sierra', 15),
#  ('Model Fish', 15),
#  ('Holes Brannigan', 15),
#  ('Valley Packer', 15),
#  ('Hysterical Grail', 15),
#  ('Devil Desire', 15),
#  ('Betrayed Rear', 15),
#  ('Holiday Games', 15),
#  ('Wasteland Divine', 15),
#  ('Labyrinth League', 15),
#  ('Charade Duffel', 15),
#  ('Steers Armageddon', 15),
#  ('Illusion Amelie', 15),
#  ('Panky Submarine', 15),
#  ('Monster Spartacus', 15),
#  ('Madison Trap', 15),
#  ('Circus Youth', 15),
#  ('Shanghai Tycoon', 14),
#  ('Nemo Campus', 14),
#  ('Virtual Spoilers', 14),
#  ('Hamlet Wisdom', 14),
#  ('Paris Weekend', 14),
#  ('Town Ark', 14),
#  ('Shane Darkness', 14),
#  ('Blindness Gun', 14),
#  ('Turn Star', 14),
#  ('Day Unfaithful', 14),
#  ('Tomatoes Hellfighters', 14),
#  ('Impossible Prejudice', 14),
#  ('Shrunk Divine', 14),
#  ('Notorious Reunion', 14),
#  ('Werewolf Lola', 14),
#  ('Greedy Roots', 14),
#  ('Image Princess', 14),
#  ('Gold River', 14),
#  ('Troopers Metal', 14),
#  ('Deep Crusade', 14),
#  ('Glass Dying', 14),
#  ('Peach Innocent', 14),
#  ('Madre Gables', 14),
#  ('Creepers Kane', 14),
#  ('Saddle Antitrust', 14),
#  ('Mother Oleander', 14),
#  ('Confessions Maguire', 14),
#  ('Outlaw Hanky', 14),
#  ('Alley Evolution', 14),
#  ('Donnie Alley', 14),
#  ('Lovely Jingle', 14),
#  ('Dances None', 14),
#  ('Games Bowfinger', 14),
#  ('Elephant Trojan', 14),
#  ('Stampede Disturbing', 14),
#  ('Grinch Massage', 14),
#  ('Home Pity', 14),
#  ('Wrath Mile', 14),
#  ('Pajama Jawbreaker', 14),
#  ('Personal Ladybugs', 14),
#  ('Stock Glass', 14),
#  ('Jaws Harry', 14),
#  ('Splash Gump', 14),
#  ('Uncut Suicides', 14),
#  ('Analyze Hoosiers', 14),
#  ('Searchers Wait', 14),
#  ('Kane Exorcist', 14),
#  ('Natural Stock', 13),
#  ('Anonymous Human', 13),
#  ('Spiking Element', 13),
#  ('Chisum Behavior', 13),
#  ('Behavior Runaway', 13),
#  ('Arabia Dogma', 13),
#  ('Super Wyoming', 13),
#  ('Exorcist Sting', 13),
#  ('Bedazzled Married', 13),
#  ('Usual Untouchables', 13),
#  ('Lawrence Love', 13),
#  ('Memento Zoolander', 13),
#  ('Saturn Name', 13),
#  ('Chamber Italian', 13),
#  ('Citizen Shrek', 13),
#  ('Moonwalker Fool', 13),
#  ('Party Knock', 13),
#  ('Hunger Roof', 13),
#  ('Everyone Craft', 13),
#  ('Connecticut Tramp', 13),
#  ('Daddy Pittsburgh', 13),
#  ('Microcosmos Paradise', 13),
#  ('Mulan Moon', 13),
#  ('Champion Flatliners', 13),
#  ('Jingle Sagebrush', 13),
#  ('Lucky Flying', 13),
#  ('Forever Candidate', 13),
#  ('Tuxedo Mile', 13),
#  ('State Wasteland', 13),
#  ('Robbery Bright', 13),
#  ('Flash Wars', 13),
#  ('Drums Dynamite', 13),
#  ('Hollywood Anonymous', 13),
#  ('Raging Airplane', 13),
#  ('Hook Chariots', 13),
#  ('Wyoming Storm', 13),
#  ('Cincinatti Whisperer', 13),
#  ('Express Lonely', 13),
#  ('Tenenbaums Command', 13),
#  ('Purple Movie', 13),
#  ('Mile Mulan', 13),
#  ('Date Speed', 13),
#  ('Identity Lover', 13),
#  ('Opposite Necklace', 13),
#  ('Spinal Rocky', 13),
#  ('Bright Encounters', 13),
#  ('Breaking Home', 13),
#  ('Sassy Packer', 13),
#  ('Past Suicides', 13),
#  ('Monterey Labyrinth', 13),
#  ('Bilko Anonymous', 13),
#  ('Darkness War', 13),
#  ('Dangerous Uptown', 12),
#  ('Vampire Whale', 12),
#  ('Alabama Devil', 12),
#  ('Tycoon Gathering', 12),
#  ('Sorority Queen', 12),
#  ('Loverboy Attacks', 12),
#  ('Evolution Alter', 12),
#  ('Uptown Young', 12),
#  ('Savannah Town', 12),
#  ('Smoochy Control', 12),
#  ('California Birds', 12),
#  ('Gunfighter Mussolini', 12),
#  ('Flight Lies', 12),
#  ('Meet Chocolate', 12),
#  ('Blanket Beverly', 12),
#  ('Crow Grease', 12),
#  ('Mighty Luck', 12),
#  ('Lost Bird', 12),
#  ('Mob Duffel', 12),
#  ('African Egg', 12),
#  ('Side Ark', 12),
#  ('Massage Image', 12),
#  ('War Notting', 12),
#  ('Born Spinal', 12),
#  ('Temple Attraction', 12),
#  ('Silverado Goldfinger', 12),
#  ('Finding Anaconda', 12),
#  ('Hedwig Alter', 12),
#  ('Window Side', 12),
#  ('Adaptation Holes', 12),
#  ('Valentine Vanishing', 12),
#  ('Minority Kiss', 12),
#  ('Liberty Magnificent', 12),
#  ('Brannigan Sunrise', 12),
#  ('Pittsburgh Hunchback', 12),
#  ('Speakeasy Date', 12),
#  ('Feathers Metal', 11),
#  ('Song Hedwig', 11),
#  ('Lord Arizona', 11),
#  ('Thin Sagebrush', 11),
#  ('Trainspotting Strangers', 11),
#  ('Opus Ice', 11),
#  ('Cranes Reservoir', 11),
#  ('Ties Hunger', 11),
#  ('Towers Hurricane', 11),
#  ('Birch Antitrust', 11),
#  ('Rider Caddyshack', 11),
#  ('Bugsy Song', 11),
#  ('Potluck Mixed', 11),
#  ('Drumline Cyclone', 11),
#  ('Bowfinger Gables', 11),
#  ('Iron Moon', 11),
#  ('Fugitive Maguire', 11),
#  ('Ending Crowds', 11),
#  ('Spirited Casualties', 11),
#  ('Magnolia Forrester', 11),
#  ('Bird Independence', 11),
#  ('Stone Fire', 11),
#  ('Mod Secretary', 11),
#  ('Prix Undefeated', 11),
#  ('Theory Mermaid', 11),
#  ('North Tequila', 11),
#  ('Frida Slipper', 11),
#  ('Reef Salute', 11),
#  ('Language Cowboy', 11),
#  ('October Submarine', 11),
#  ('Autumn Crow', 11),
#  ('Beethoven Exorcist', 11),
#  ('Stranger Strangers', 11),
#  ('Twisted Pirates', 11),
#  ('Santa Paris', 11),
#  ('Dragon Squad', 11),
#  ('Gathering Calendar', 11),
#  ('Darko Dorado', 11),
#  ('Beast Hunchback', 11),
#  ('Run Pacific', 10),
#  ('Frogmen Breaking', 10),
#  ('Notting Speakeasy', 10),
#  ('Stage World', 10),
#  ('Fiddler Lost', 10),
#  ('Hollow Jeopardy', 10),
#  ('Element Freddy', 10),
#  ('Grail Frankenstein', 10),
#  ('Lambs Cincinatti', 10),
#  ('Luck Opus', 10),
#  ('Rollercoaster Bringing', 10),
#  ('Wars Pluto', 10),
#  ('Sensibility Rear', 10),
#  ('Wagon Jaws', 10),
#  ('Jawbreaker Brooklyn', 10),
#  ('Elizabeth Shane', 10),
#  ('Madigan Dorado', 10),
#  ('Superfly Trip', 10),
#  ('Jeopardy Encino', 10),
#  ('Paths Control', 10),
#  ('Lolita World', 10),
#  ('Life Twisted', 10),
#  ('Blood Argonauts', 10),
#  ('Mystic Truman', 10),
#  ('Amelie Hellfighters', 10),
#  ('Lover Truman', 10),
#  ('Antitrust Tomatoes', 10),
#  ('Maker Gables', 10),
#  ('Gone Trouble', 10),
#  ('Reservoir Adaptation', 10),
#  ('Doubtfire Labyrinth', 10),
#  ('Spoilers Hellfighters', 10),
#  ('Smile Earring', 10),
#  ('Oleander Clue', 10),
#  ('Right Cranes', 10),
#  ('Halloween Nuts', 10),
#  ('Beneath Rush', 10),
#  ('Clockwork Paradise', 10),
#  ('Victory Academy', 9),
#  ('Wonderful Drop', 9),
#  ('Anything Savannah', 9),
#  ('Dares Pluto', 9),
#  ('Casualties Encino', 9),
#  ('Matrix Snowman', 9),
#  ('Reds Pocus', 9),
#  ('Miracle Virtual', 9),
#  ('Legend Jedi', 9),
#  ('Legally Secretary', 9),
#  ('Vanilla Day', 9),
#  ('Won Dares', 9),
#  ('Zhivago Core', 9),
#  ('Dwarfs Alter', 9),
#  ('Wisdom Worker', 9),
#  ('Montezuma Command', 9),
#  ('Nuts Ties', 9),
#  ('Guys Falcon', 9),
#  ('Ghostbusters Elf', 9),
#  ('Speed Suit', 9),
#  ('Caribbean Liberty', 9),
#  ('Darling Breaking', 9),
#  ('Drop Waterfront', 9),
#  ('Ali Forever', 9),
#  ('Platoon Instinct', 9),
#  ('Spartacus Cheaper', 9),
#  ('Dolls Rage', 9),
#  ('Hotel Happiness', 9),
#  ('Random Go', 9),
#  ('Intolerable Intentions', 9),
#  ('Birdcage Casper', 9),
#  ('Daughter Madigan', 9),
#  ('Gilbert Pelican', 9),
#  ('Impact Aladdin', 9),
#  ('King Evolution', 9),
#  ('Holy Tadpole', 9),
#  ('Jungle Closer', 9),
#  ('Frisco Forrest', 9),
#  ('Snatchers Montezuma', 9),
#  ('Diary Panic', 9),
#  ('Maguire Apache', 9),
#  ('Kramer Chocolate', 9),
#  ('Crazy Home', 9),
#  ('Monsoon Cause', 9),
#  ('Magnificent Chitty', 8),
#  ('Jumanji Blade', 8),
#  ('World Leathernecks', 8),
#  ('Sunset Racer', 8),
#  ('Hoosiers Birdcage', 8),
#  ('Casper Dragonfly', 8),
#  ('Lights Deer', 8),
#  ('Records Zorro', 8),
#  ('Desire Alien', 8),
#  ('Unfaithful Kill', 8),
#  ('Rebel Airport', 8),
#  ('Clyde Theory', 8),
#  ('Runner Madigan', 8),
#  ('Pet Haunting', 8),
#  ('Crusade Honey', 8),
#  ('Runaway Tenenbaums', 8),
#  ('Baby Hall', 8),
#  ('Soldiers Evolution', 8),
#  ('Ballroom Mockingbird', 8),
#  ('Chitty Lock', 8),
#  ('Vertigo Northwest', 8),
#  ('Shining Roses', 8),
#  ('Punk Divorce', 8),
#  ('Godfather Diary', 8),
#  ('Harold French', 8),
#  ('Papi Necklace', 8),
#  ('Tarzan Videotape', 8),
#  ('Untouchables Sunrise', 8),
#  ('Soup Wisdom', 8),
#  ('Destination Jerk', 8),
#  ('Maude Mod', 8),
#  ('Park Citizen', 8),
#  ('Gosford Donnie', 8),
#  ('Grosse Wonderful', 8),
#  ('Chaplin License', 8),
#  ('Saints Bride', 8),
#  ('Bang Kwai', 7),
#  ('Squad Fish', 7),
#  ('Ishtar Rocketeer', 7),
#  ('Sense Greek', 7),
#  ('Heavenly Gun', 7),
#  ('Fire Wolves', 7),
#  ('Pizza Jumanji', 7),
#  ('Mulholland Beast', 7),
#  ('Menagerie Rushmore', 7),
#  ('Vision Torque', 7),
#  ('Bulworth Commandments', 7),
#  ('Clerks Angels', 7),
#  ('Hawk Chill', 7),
#  ('Luke Mummy', 7),
#  ('Lesson Cleopatra', 7),
#  ('Young Language', 7),
#  ('Divorce Shining', 7),
#  ('License Weekend', 7),
#  ('Vanished Garden', 7),
#  ('Cruelty Unforgiven', 7),
#  ('Clue Grail', 7),
#  ('Dozen Lion', 7),
#  ('Ace Goldfinger', 7),
#  ('Duffel Apocalypse', 7),
#  ('Doctor Grail', 7),
#  ('President Bang', 7),
#  ('Connection Microcosmos', 7),
#  ('Treatment Jekyll', 7),
#  ('Stallion Sundance', 7),
#  ('Control Anthem', 7),
#  ('Early Home', 7),
#  ('Elf Murder', 7),
#  ('Cowboy Doom', 7),
#  ('Magic Mallrats', 7),
#  ('Newsies Story', 7),
#  ('Eve Resurrection', 7),
#  ('Leathernecks Dwarfs', 7),
#  ('Panic Club', 7),
#  ('Terminator Club', 6),
#  ('Simon North', 6),
#  ('Killer Innocent', 6),
#  ('Wild Apollo', 6),
#  ('Texas Watch', 6),
#  ('Warlock Werewolf', 6),
#  ('Sling Luke', 6),
#  ('Frontier Cabin', 6),
#  ('Duck Racer', 6),
#  ('Graceland Dynamite', 6),
#  ('Tequila Past', 6),
#  ('Jersey Sassy', 6),
#  ('School Jacket', 6),
#  ('Comancheros Enemy', 6),
#  ('Bubble Grosse', 6),
#  ('Watership Frontier', 6),
#  ('Happiness United', 6),
#  ('Apocalypse Flamingos', 6),
#  ('Haunted Antitrust', 6),
#  ('Italian African', 6),
#  ('Bed Highball', 6),
#  ('Youth Kick', 6),
#  ('Cassidy Wyoming', 6),
#  ('Phantom Glory', 6),
#  ('Ladybugs Armageddon', 6),
#  ('Japanese Run', 6),
#  ('Oklahoma Jumanji', 6),
#  ('Extraordinary Conquerer', 6),
#  ('Dumbo Lust', 6),
#  ('Desperate Trainspotting', 6),
#  ('Rushmore Mermaid', 6),
#  ('Mannequin Worst', 5),
#  ('Seven Swarm', 5),
#  ('Glory Tracy', 5),
#  ('Braveheart Human', 5),
#  ('Bunch Minds', 5),
#  ('Freedom Cleopatra', 5),
#  ('Informer Double', 5),
#  ('Full Flatliners', 5),
#  ('Traffic Hobbit', 5),
#  ('Hunter Alter', 5),
#  ('Private Drop', 5),
#  ('Fever Empire', 5),
#  ('Mussolini Spoilers', 5),
#  ('Conspiracy Spirit', 5),
#  ('Hardly Robbers', 4),
#  ('Mixed Doors', 4),
#  ('Train Bunch', 4)]

# %%
# суммарные доходы магазинов
con.execute("""
SELECT s.store_id, SUM(p.amount) sales FROM store s 
JOIN staff st ON s.store_id = st.store_id
JOIN payment p ON st.staff_id = p.staff_id
GROUP BY s.store_id;
""").fetchall()
# Out:
# [(1, Decimal('30252.12')), (2, Decimal('31059.92'))]

# %%
# найдем города и страны каждого магазина
con.execute("""
SELECT store_id, city, country FROM store s 
JOIN address a ON s.address_id = a.address_id
JOIN city ON a.city_id = city.city_id
JOIN country c ON city.country_id = c.country_id;
""").fetchall()
# Out:
# [(1, 'Lethbridge', 'Canada'), (2, 'Woodridge', 'Australia')]

# %%
# выведем топ-5 жанров по доходу
con.execute("""
SELECT c.name, SUM(p.amount) revenue FROM category c 
JOIN film_category fc ON c.category_id = fc.category_id
JOIN inventory i ON fc.film_id = i.film_id
JOIN rental r ON i.inventory_id = r.inventory_id
JOIN payment p ON r.rental_id = p.rental_id
GROUP BY c.name
ORDER BY revenue DESC 
LIMIT 5;
""").fetchall()
# Out:
# [('Sports', Decimal('4892.19')),
#  ('Sci-Fi', Decimal('4336.01')),
#  ('Animation', Decimal('4245.31')),
#  ('Drama', Decimal('4118.46')),
#  ('Comedy', Decimal('4002.48'))]
